# %% [markdown]
# <a href="https://colab.research.google.com/github/mehadisaki/SomikoronAI_ans/blob/main/Result_of_nlp_testscript_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Somikorno AI
#
# ## Quick Test : NLP Problem 1
#
# #### Extract Scanned PDF

# %% [markdown]
# #### Goal
#
# To extract all Bangla words from a scanned pdf file.
#
#
# To successfully run this notebook you would need to have the followiing packages installed:
#
# 1. numpy
#
# 2. pandas
#
# 3. opencv
#
# 4. pytesseract
#
# 5. pdf2image

# %% [markdown]
# ### Load Required Packages

# %%
import numpy as np
import pandas as pd
import os
import re
import json

# %%
# !pip3 install opencv
#!pip3 install pytersseract
# !pip3 install pdf2image
#!pip install opencv-python
#!pip install pytesseract
#!pip install pdf2image

# %%
# !pip install opencv-python
# !pip install pytesseract
# !pip3 install pdf2image
#!pip install opencv-python
#!pip install pytesseract
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting Pillow>=8.0.0
#   Downloading Pillow-9.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 4.9 MB/s
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Installing collected packages: Pillow, pytesseract
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed Pillow-9.3.0 pytesseract-0.3.10
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pdf2image
#   Downloading pdf2image-1.16.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from pdf2image) (9.3.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.0

# %%
import cv2
import pytesseract
from pdf2image import convert_from_path

# %% [markdown]
# ###Install dependency

# %%
# !sudo apt install tesseract-ocr
# !pip  install poppler-utils
# !pip install Pillow
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: poppler-utils in /usr/local/lib/python3.8/dist-packages (0.1.0)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.8/dist-packages (from poppler-utils) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (9.3.0)

# %%
pytesseract.pytesseract.tesseract_cmd = (r'/usr/bin/tesseract')

# %%
# !wget https://poppler.freedesktop.org/poppler-21.09.0.tar.xz;
# !tar -xvf poppler-21.09.0.tar.xz
# !mkdir -p poppler-21.09.0/build && \
cd poppler-21.09.0 && \
cmake  -DCMAKE_BUILD_TYPE=Release   \
       -DCMAKE_INSTALL_PREFIX=/usr  \
       -DTESTDATADIR=$PWD/testfiles \
       -DENABLE_UNSTABLE_API_ABI_HEADERS=ON && \
make && \
make install

# %% [markdown]
# ### Part 1 : Read Data
#
# Read the `data_testscript_01.pdf` file from your working directory

# %%
pdf_file = '/content/data_testscript_02.pdf'

# %% [markdown]
# Uploading Bangla trian data file  ben.traindata to "/usr/share/tesseract-ocr/4.00/tessdata/" path

# %%
filenames = os.listdir('/usr/share/tesseract-ocr/4.00/tessdata/')
print(filenames)
# Out:
# ['tessconfigs', 'configs', 'pdf.ttf', 'osd.traineddata', 'ben.traineddata', 'eng.traineddata']

# %% [markdown]
# Read all pages as a Python list
#
# if unfamiliar with the following function, try: help(convert_from_path)

# %%
pages = convert_from_path(pdf_file, dpi=200, poppler_path='/usr/bin/', output_folder=None, first_page=None, last_page=None)

# %% [markdown]
# Main OCR function

# %%
def main_ocr(current_page, color, black):
    """
    Inputs : 
    scanned page
    color of the page
    
    Output : 
    text output from image_to_string method
    
    """
    
    # step 1 
    current_page.save('temp1.jpg', 'JPEG') # save current page as JPEG
    
    
    # step 2
    if color == 'g': # color parameter
        read_image = cv2.imread("temp1.jpg", cv2.IMREAD_COLOR)     # image read
        gray_image = cv2.cvtColor(read_image, cv2.COLOR_BGR2GRAY)  # turn image to gray.
        cv2.imwrite("temp2.jpg", gray_image)               # save as gray
        
    elif color == 'b':
        read_image = cv2.imread("temp1.jpg", cv2.IMREAD_COLOR)     # image read
        gray_image = cv2.cvtColor(read_image, cv2.COLOR_BGR2GRAY)  # turn image to gray.
        (thresh, BnW_image) = cv2.threshold(gray_image, black, 255, cv2.THRESH_BINARY) # this controls color temp
        cv2.imwrite("temp2.jpg", BnW_image)                # save as black and white

    
    # step 3
    text = pytesseract.image_to_string('temp2.jpg', lang='ben') # scan page

    return text

# %% [markdown]
# Total number of pmages read

# %%
total_page = len(pages)
total_page
# Out:
# 25

# %% [markdown]
# Main Data Processing Section

# %%
# test complete? if yes then continue

start_page = 0          # first page
end_page = total_page   # last page

dataList = []   # storage of each page as a list

for i in range(start_page, end_page):
    print("Scaning page:", i+1)
    dataList.append( main_ocr(pages[i], 'g', 160) )
# Out:
# Scaning page: 1
# Scaning page: 2
# Scaning page: 3
# Scaning page: 4
# Scaning page: 5
# Scaning page: 6
# Scaning page: 7
# Scaning page: 8
# Scaning page: 9
# Scaning page: 10
# Scaning page: 11
# Scaning page: 12
# Scaning page: 13
# Scaning page: 14
# Scaning page: 15
# Scaning page: 16
# Scaning page: 17
# Scaning page: 18
# Scaning page: 19
# Scaning page: 20
# Scaning page: 21
# Scaning page: 22
# Scaning page: 23
# Scaning page: 24
# Scaning page: 25

# %% [markdown]
# ### Paer 2: Clean Data
#
# #### Split each page using `pattern='\n'`

# %%
data = dataList.copy()

for i, _data in enumerate(dataList):    # i index & data
    data[i] = _data.split("\n")                     # split where "\n"

# %% [markdown]
# The pages of the book now appears as a list of lists.
#
# Pages are all full of punctuation marks and special characters

# %%
# Have a look at the data
data
# Out:
# [['অন্তরার বাবা',
#   '',
#   'মফিজাউদ্দিন সাহেব নির্বিরোধী মানুষ। প্রাইভেট ব্যাংকে ফরেন এক্সচেঞ্জ বিভাগে',
#   'কাজ করেন। ঢাকার মালিবাগে ফ্ল্যাট ভাড়া করে থাকেন। চিপা গলির ভেতর ফ্ল্যাট।',
#   'গাড়ি ঢোকে না বলে বেশ সম্তা। চার রুমের বাইশ শ স্কয়ার ফিটের ফ্ল্যাট। তাড়া',
#   'তিন হাজার টাকা। মফিজউদ্দিন সাহেবের সংসার ছোট। স্ত্রী, দুই মেয়ে, এক',
#   'ছেলে। বড় মেয়েটির বিয়ে হয়ে গেছে। কানাডায় স্বামীর সঙ্গে থাকে। ছোট',
#   'মেয়েটিরও বিয়ের কথা হচ্ছে। পাত্র পক্ষ মেয়ে দেখে গেছে। ফাইন্যাল কিছু না',
#   'বললেও মেয়ে যে তাদের খুব পছন্দ এটা বোঝা যাচ্ছে। ছেলেটাও পড়াশোনায়',
#   'তভালো। জ্বলাই মাসে অনার্স পরীক্ষা দেবে। পাস করে বের হয়ে কোথাও চাকরি না',
#   'পেলে ব্যাহকে চাকরি হবেই ৷ মফিজউদ্দিন সাহেব তার ব্যাংকের এমডি সাহেবকে',
#   'বলে রেখেছেন।',
#   '',
#   'কাজেই মফিজউদ্দিন সাহেবকে মোটামুটি সফল এবং সুখী মানুষ বলা যেতে',
#   'পারে। তার স্ত্রী-ভাগ্যও ভালো। রেহানা অতি শান্ত স্বতাবের মেয়ে । স্বামীর সঙ্গে তার',
#   'যে ঝগড়াটগড়া হয় না তা না, মাঝেমধ্যে হয়। তবে তখনো যফিজ সাহেবের কী',
#   'দরকার কী দরকার না তার দিকে কঠিন নজর থাকে৷',
#   '',
#   'ব্যাংক থেকে ফিরতে মফিজ সাহেবের রোজই সন্ধ্যা সাতটা-আটটা বেজে',
#   'যায়। তিনি ফিরেই গরম পানি দিয়ে গোসল কবেন। গোসল সেরেই খেতে বসেন।',
#   'খাওয়া শেষ করে মিনিট দশেক চোখ বন্ধ করে শুয়ে থাকেন, তারপর এসে টিভির',
#   'সামনে বসেন। নাটক থাকলে নাটক দেখেন। নাটক না থাকলে ভিসিপিতে হিন্দি',
#   'ছবি দেখেন। পুরোনো ছবি দুবার-তিনবার করে দেখতেও তাঁর কোনো আপত্তি',
#   'নেই। তবে পুরোনো ছবি যেন তাকে দেখতে না হয় রেহানার সেদিকেও নজর',
#   'আছে। বাসায় কেউ না থাকলে তিনি নিজেই ভিডিও রব থেকে ছবি নিয়ে আসেন।',
#   'হিন্দি ছবি দেখার ব্যাপারে তার কোনো আগ্রহ নেই, তবু স্বামীকে খুশি করার জন্যে',
#   '\x0c'],
#  ['তিনি বলেন- নাচ-গান আসলে আমাকে ডাক দিও তো। তোমার সঙ্গে বসে',
#   'দেখব। মফিজ সাহেব সুবোধ স্বামীর মতো নাচ-গানের জায়গা এলে স্ত্রীকে',
#   'ছাকেন।',
#   '',
#   'স্বামী-স্ত্রীর সাংসারিক কথাবার্তা ছবি দেখার সময়ই হয়। কারণ মফিজ সাহেব',
#   "ছবি শেষ করেই ঘুমাতে যান। তাকে খুব ভোরে উঠতে হয়। প্রাইভেট ব্যাংক, ন'টা",
#   'থেকে ব্যাংকিং আওয়ার ।',
#   '',
#   'মফিজ সাহেবের জীবনযাত্রা এভাবেই চলছিল। এক বুধবারে সামান্য ব্যতিক্রম',
#   'হল। তিনি পলিথিনের এক পোটলা নিয়ে অফিস থেকে ফিরে যথারীতি গোসল করতে',
#   'গেলেন। গোসলের মাঝখানে রেহানা বাথরুমের দরজায় ধাক্কা দিয়ে বললেন, পোলার',
#   'ভেতর কাপড় কিসের?',
#   '',
#   'মফিজ সাহেব বললেন, আমার কাপড় ৷',
#   '',
#   "'তোমার কী কাপড়?”",
#   '',
#   "'কিনলাম আর কি?'",
#   '',
#   "'কিনবে তো বটেই । বিনা টাকায় তোমাকে কে কাপড় দিবে? কিসের কাপড়?",
#   '',
#   "'কাফনের কাপড় ''",
#   '',
#   "'কাফনের কাপড় মানে কী?'",
#   '',
#   'মফিজ সাহেব জবাব দিলেন না। মাথায় পানি ঢালতে লাগলেন। রেহানা বললেন,',
#   'জবাব দিচ্ছ না কেন কাফনের কাপড় মানে কী? কার কাফনের কাপড়? তোমার কথা',
#   'তো কিছুই বুঝতে পারছি না। তৃমি কি মারা গেছ নাকি যে তোমার কাফনের কাপড়ঃ',
#   'গোসলটা একটু বন্ধ রেখে কথার জবাব দাও তো।',
#   '',
#   "*আমার এক কলিগ হজ করতে গিয়েছিলেন। তাকে আনতে বলেছিলাম।'",
#   '',
#   "'মক্কা থেকে তোমার জন্যে কাফনের কাপড় আনতে বলেছ? কেন দেশে সাদা",
#   'কাপড় পাওয়া যায় না?”',
#   '',
#   "'কাবা শরিফ ছুয়ায়ে এনেছে।'",
#   '',
#   "'কাবা শরিফ ছুঁয়ায়ে তোমার জন্যে কাফনের কাপড় আনতে হবে কেন?'",
#   '',
#   'মফিজ সাহেব গোসল শেষ করে বের হলেন। শাস্ত গলায় রললেন, ভাত দাও।',
#   '',
#   "'ভাত দাও মানে! তুমি আগে বল কাফনের কাপড় কী মনে করে আনালে!'",
#   '',
#   'মফিজ সাহেব জবাব দিলেন না। খাবার টেবিলের দিকে রওনা হলেন।',
#   '',
#   'বিয়ের কথা ঠিকঠাক হবার পর কোন এক বিচিত্র কারণে মেয়েরা বাবার দিকে',
#   'চলে আসে। অতিরিক্ত মমতা দেখায়। খানিকটা আহ্লারদীও করে। মফিজউদ্দিন',
#   'সাহেবের মেয়ে অন্তরার তেতরও এই ব্যাপার হয়েছে। সে তার ঘরে বসে ছিল।',
#   'মায়ের চেঁচামেচি শুনে বিরক্ত মুখে বলল, এ রকম করছ কেন মা?',
#   '\x0c'],
#  ['রেহানা বললেন, কী করছি? তোর বাবা কী করেছে শুনতে পাস নিঃ কাফনের',
#   'কাপড় নিয়ে এসেছে।',
#   '',
#   '“*কী হয়েছে তাতে? অনেকেই আনে। শুধু শুধু চেঁচিও না তো মা। একটা মানুষ',
#   'সারা দিন অফিস করে এসেছে তাকে তুমি রেস্ট দেবে না? চিৎকার করে মাথার পোকা',
#   "নড়িয়ে দিচ্ছ।'",
#   '',
#   "'এই কাফনের কাপড় আমি কিন্তু ঘরে রাখব না।'",
#   '',
#   "'আচ্ছা রেখো না। এখন দয়া করে চিৎকার থামাও। ভাত খাবার পর বাবা মুভি",
#   'দেখবে--নতুন কিছু এনেছ? না আনলে স্লিপ দিয়ে কাজের মেয়েটাকে পাঠাও। বেচারা',
#   'রোজ পুরোনো মুভি দেখে, আমার খুব খারাপ লাগে৷ মাদার ইন্ডিয়া ছবিটা এই নিয়ে',
#   'তিনবার দেখল। তিনবার দেখার মতো কী আছে?”',
#   '',
#   'অন্তরা তার বাবার খাবার সময়ও কিছুক্ষণ সামনে বসে রইল। প্লেটে ভাত তুলে',
#   'দিল। মফিজউদ্দিন সাহেব নিঃশব্দে খেয়ে গেলেন। এমনিতেই তিনি কথা কম বলেন,',
#   'খাবার সময় একেবারেই বলেন না।',
#   '',
#   'মফিজউদ্দিন খেয়েদেয়ে অন্য দিনের মতো রেস্ট নিতে গেলেন না। সরাসরি ছবি',
#   'দেখতে গেলেন। অন্তরা টেলিফোন নিয়ে তার নিজের ঘরে ঢুকে ভেতর থেকে দরজা',
#   "লাপিয়ে দিল। যে ছেলের সঙ্গে বিয়ে ঠিক হয়েছে রোজ রাত ন'টার সময় সে",
#   'টেলিফোন করে। টেলিফোনে এক ঘণ্টার মতো কথা হয়। এক ঘণ্টা কথায় অনেক',
#   'কিছু চলে আসে। অন্তরা তার বাবার কাফনের কাপড় কেনার প্রসঙ্গ নিয়ে এল-_',
#   '',
#   "'এই জান আজ কী হয়েছে? ভয়ঙ্কর কাণ্ড হয়েছে।'",
#   '',
#   "'কী হয়েছে?",
#   '',
#   "'আমার বাবা অর্থাৎ তোমার শ্বশুর সাহেব ভয়ঙ্কর একটা কাণ্ড করেছেন।'",
#   '',
#   "'কী কাণ্ড!",
#   '',
#   "'আন্দাজ কর তো, দেখি পার কি না।'",
#   '',
#   '“আন্দাজ করতে পারছি না। উনি কী ভয়ঙ্কর কাগু করেছেন?',
#   '',
#   '*উনি বলছ কেন?”',
#   '',
#   "'উনি বলব না তো কী বলবঃ'",
#   '',
#   "বাবা বলবে।'",
#   '',
#   "'এখনই বাবা বলব নাকি?'",
#   '',
#   "'হ্যা এখনই বাবা বলবে। আমি তো তোমার মাকে এখনই মা বলি।'",
#   '',
#   "'কবে মা বললে?'",
#   '',
#   "'ওমা এর মধ্যে ভুলে গেছ! কাল আমি জিজ্ঞেস করলাম না, মা কেমন আছেন।",
#   "আমি কি বলেছি তোমার মা কেমন আছেন?'",
#   '',
#   "(ও আচ্ছা। এখন মনে পড়েছে।'",
#   '\x0c'],
#  ["'তোমার এমন ভূলোমন, কোন দিন আমাকে ভুলে যাবে! কে জানে হয়তো",
#   'এখনই ভুলে যাবে। বল তো আমার নাম কী?”',
#   '',
#   "'আসলেই তো ভুলে গেছি তোমার নাম যেন কী?",
#   '',
#   "'ফাজলামি করবে না তো।'",
#   '',
#   "'আচ্ছা যাও ফাজলামি করব না। তোমাদের বাসায় ভয়ঙ্কর ব্যাপাব কী হল তা",
#   "কিছু এখনো বল নি।'",
#   '',
#   "'আমার বাবা কাফনের কাপড় কিনে নিয়ে এসেছেন।'",
#   '',
#   "'সে কী! কার জন্যে?'",
#   '',
#   "'কার জন্যে আবার, নিজের জন্যে ।'",
#   '',
#   "'বল কী! মাথা খারাপ নাকি?'",
#   '',
#   "“নিজের খুবত্তর সম্পর্কে এসব কী বলছ, ছিঃ!'",
#   '',
#   "*'আই আম সরি। তবে জঅস্তরা শোন কাফনের কাপড় কিন্তু অনেকেই কেনে।",
#   'আমার এক দূরসম্পর্কের নানা কিনেছিলেন। শেষে দেখা গেল- তার সংসারের সবাই',
#   "মারা গেছে তিনি শুধু বেঁচে আছেন। তার আর মৃত্যু হচ্ছে না।'",
#   '',
#   "'আসলে বাবা হচ্ছেন খুবই স্টেপ্র মানুষ। তিনি নিজের মতো থাকেন। অফিস",
#   "করেন। কোনো বিষয়ে তার কোনো কমপ্লেইন নেই ।'",
#   '',
#   "'কাফনের কাপড় কিনে এনে কী বললেন?”",
#   '',
#   "'কিছুই বলেন নি। তিনি নিজের মতো আছেন। এখন ছবি দেখছেন।'",
#   '',
#   "'কার ছবি দেখছেনঃ'",
#   '',
#   '*তিসিআরব-এ ছবি দেখছেন। বাবার এই একটা শখ- ছবি দেখা। এখন দেখছেন',
#   "ঠান্ডি হাওয়া ৷ তুমি ঠাণ্ডি হাওয়া দেখেছ?'",
#   '',
#   "'না।",
#   '',
#   "'গানগুলি এত সুন্দর। শুনলে পাগল হয়ে যেতে হয়। আচ্ছা আমি তোমাকে",
#   "ক্যাসেট পাঠিয়ে দেব।'",
#   '',
#   "'পাঠিয়ে দিতে হবে না। আমি নিজে এসে নিয়ে যাব।'",
#   '',
#   "'খবরদার এই কাজ করবে না। বিয়ের আগে শ্বশুরবাড়িতে ঘোরাঘুরি আমার খুব",
#   "জপছন্দ।'",
#   '',
#   "*'অপছন্দ হলেও এই কাজটা আমাকে করতে হবে। রাজকন্যাকে না দেখে আমি",
#   "থাকতে পারছি না।'",
#   '',
#   "'খবরদার ঢং করবে না। আচ্ছা তুমি এত ঢং কোথায় শিখেছ?'",
#   '',
#   "'আমার ইচ্ছা করছে এখনই চলে আসি। আমি গোপনে এসে চুপ করে তোমার",
#   "দরজায় টোকা দেব। তুমি দরজা খুলতেই ঝপাং।'",
#   '',
#   "'ঝপাৎ মানে",
#   '\x0c'],
#  ["'বঝপাং করে তোমার গায়ে লাফিয়ে পড়ব।'",
#   '',
#   "'এই শোন তৃমি কিন্তু কথাবার্তা অসতভ! দিকে নিয়ে যাচ্ছ। এ রকম করলে আমি",
#   "কিন্তু টেলিফোন বেখে দেব।'",
#   '',
#   "'উই রাখতে পারবে না। কারণ আমাদের কথা হয়েছিল আমি একটা অসত্য কথা",
#   "বলতে পারি।'",
#   '',
#   "'একটা বলে ফেলেছ আর পারবে না।'",
#   '',
#   "'এখনো বলি নি।'",
#   '',
#   '"আমি কিন্তু টেলিফোন রেখে দিচ্ছি। এই রাখলাম, ওয়ান, টু, থ্রি।\'',
#   '',
#   'অন্তরা টেলিফোন নামিয়ে রিগার অফ করে দিল। ওপাশ থেকে টেলিফোন করে',
#   'করে ক্লান্ত হোক। মজা বুঝুক। রাত বারটার পর অন্তবা নিজেই করবে। এর মধ্যে',
#   'অসত্য কথা বলার জন্যে বাবু সাহেবের যথেষ্ট শিক্ষা হয়ে যাবে।',
#   '',
#   'অন্তরা মাকে নিয়ে খেতে বসল। সাজ্জাদ বাসায় নেই৷ সে তার বন্ধুর বাড়িতে',
#   'পড়াশোনা করতে পগিয়েছে। পড়াশোনা শেষ করে রাতে সেখানেই থেকে যাবে। অস্তরা',
#   'বলল, কাজের মেয়েটাকে বল তো মা বাবাকে এক কাপ চা দিয়ে আসুক ছবি দেখার',
#   'সময় চা খেতে ভালো লাগে ।',
#   '',
#   'রেহানা বললেন, তোর বাবার চা-কফি কিছুই লাগে না। কাপে করে গরম পানি',
#   'দিয়ে আয়। চুকচুক করে গরম পানি খাবে আর ছবি দেখবে। ছবিও কিন্তু দেখে না।',
#   'ঘটনা কী জিজ্ঞেস কর, বলতে পারবে না।',
#   '',
#   "'কী যে তুমি বল! কেন বলতে পারবে না?",
#   '',
#   "'তাকিয়ে থাকার জন্যে তাকিয়ে থাকা ৷'",
#   '',
#   '"তুমি বাবার ওপর রেগে আছ বলে এরকম কথা বলছ।\'',
#   '',
#   '"রাগের মতো কাজ করলে আমি রাগব না!\'',
#   '',
#   "'বাবা মোটেই রাগের মতো কাণ্ড করে নি। কাফনের কাপড় অনেকেই কেনে।",
#   'আমার এক খুব ক্লোজ ফ্রেন্ডের নানা কিনেছিলেন। তার পর কী হয়েছে শোন মা। তার',
#   'সংসারের সবাই একে একে মরে গেলেন। তিনি শুধু বেঁচে রইলেন। অমর হয়ে',
#   'গেলেন। বাবার বেলাতেও বোধহয় এরকম হবে। দেখা যাবে বাবা বেঁচে আছেন।',
#   "আমরা সবাই মরে ভূত হয়ে গেছি। হি-হি-হি।'",
#   '',
#   'রেহানা মুখ কালো করে বললেন, হাসছিস কেন? হাসির কী হল?',
#   '',
#   '“হাসি আসছে আমি করব কী? মাগো কী অদ্ভুত দৃশ্য বাবা কাফনের কাপড় পরে',
#   "ঘুরে বেড়াচ্ছে আমরা সবাই মরে ভূত হয়ে বিভিন্ন গাছে বাস করছি। হি-হি-হি।'",
#   '',
#   "'হাসি বন্ধ কর। বন্ধ কর বললাম।'",
#   '',
#   'অন্তরা হাসি বন্ধ করতে পারল না। হাসির ফাকে ফাকে বলল, মা, ডতৃত হয়ে আমি',
#   'কিন্তু বগনভিলিয়া গাছটায় থাকব তুমি অন্য কোনো গাছ বেছে নাও। হি-হি-হি।',
#   '\x0c'],
#  ['অস্তরার ইচ্ছা করছে ভূতবিষয়ক এই মজার ব্যাপারটা এক্ষুনি টেলিফোন করে',
#   'আসল মানুষটাকে জানায়। তবে ইচ্ছা করলেও এই কাজটা সে এখন করবে না। রাত',
#   'বারটার আগে অবশ্যই না। রাত বারটা পর্যন্ত বাবু সাহেব টেলিফোনে আঙুল টিপে',
#   'টিপে ক্লান্ত হয়ে নিক। অসত্য কথা বলার মজাটা টের পাক।',
#   '',
#   'রেহানা ঘরের কাজ শেষ করে ঘুমাতে যাবার আগে ঘড়ির দিকে তাকালেন, দশটা',
#   'বেজে এগার মিনিট অন্তরার বাবা নিশ্চয়ই ঘুমিয়ে পড়েছে। ঠিক দশটায় সে দাত',
#   "মেঙ্জে বিছানায় যায়। তার বিছানায় যাওয়া মানেই ঘুম। তখন ডাকলে 'উ' করে সাড়া",
#   'দেয় ঠিকই, কিন্তু সেই সাড়া দেয়াটাও হয় ঘুমের মধ্যে । আশ্চর্য একটা মানুষ।',
#   'সংসারে কী হচ্ছে কী না হচ্ছে কোনো খোজ নেই। ছেলেটা আজ বাসায় নেই এটাও',
#   'তার চোখে পড়ল না। চোখে পড়লেও অবিশ্যি কিছু হবে না। জিজ্ঞেস করবে না, সে',
#   'কোথায়। বাসায় একটা বিয়ে হচ্ছে। জিনিসপত্র কেনাকাটা আছে। বিয়ের তারিখ ঠিক',
#   'করা আছে-_কোনোটার সঙ্গে কোনো যোগ নেই। সে আছে নিজের মতো, মাস শেষে',
#   'বেতনের টাকাটা তুলে দিলেই যেন সব দায়িত্ব শেষ। এরকম মানুষের আসলে সংসার',
#   'করাই ঠিক না। এরা আসলে মানুষও না। ঘরের আসবাব। সংসারে এদের ভূমিকা',
#   'ফার্নিচারের মতো। জায়গামতো ফার্নিচারটা বসিয়ে দাও। মাঝেমধ্যে ঝাড়া দিয়ে',
#   'বেড়ে ধুলা উড়িয়ে দাও-_সব ঠিক ৷',
#   '',
#   'রেহানা পান মুখে দিয়ে অন্তরার ঘরের দিকে গেলেন। তারও কথা বলার মানুষ',
#   'নেই। মেয়ের সঙ্গে কিছুক্ষণ গল্প করা। সেই সুযোগও বেশি দিন পাওয়া যাচ্ছে না।',
#   'বিয়ে হয়ে মেয়ে চলে যাচ্ছে',
#   '',
#   'রেহানা অন্তরার ঘরে চুকতেই অন্তরা বলল, মা আজ তোমার সঙ্গে গল্প করতে',
#   'পারব না। জজ যাও তো।',
#   '',
#   "'কী করবি? টেলিফোন নিয়ে বসবি?'",
#   '',
#   "'টেলিফোন নিয়ে বসব মানে, আমি কি সারাক্ষণ টেলিফোন নিয়ে থাকি?",
#   '',
#   "'যখনই তোর ঘরের সামনে দিয়ে যাই তখনই দেখি শুটুরগুটুর করছিস। বিয়ের",
#   "আগে এত কথা বলে ফেললে বিয়ের পর কী বলবি?'",
#   '',
#   '"আশ্চর্য কথা! তোমার ধারণা দেখে অবাক হচ্ছি মা। তুমি ভাবছ আমি ওর সঙ্গে',
#   'কথা বলি? আমার এত কী দায় পড়েছে? আজ সে টেলিফোন করেছিল। আমি মুখের',
#   'ওপর টেলিফোন রেখে দিয়ে রিংগার অফ করে দিয়েছি যাতে টেলিফোন করলেও',
#   "আমাকে ধরতে না হয়।'",
#   '',
#   "'সে কী! কেনঃ'",
#   '',
#   "'আমার কথা বলতে ইচ্ছা করে না এই জন্যে ।'",
#   '',
#   "'এটা তো ঠিক না, মুখের ওপর টেলিফোন রেখে দিবি কেন?'",
#   '\x0c'],
#  ["'কোনটা ঠিক কোনটা ঠিক না তা নিয়ে তোমাকে বক্তৃতা দিতে হবে না মা। প্রিজ",
#   "তুমি এখন যাও। তোমাকে অসহ্য লাগছে।'",
#   '',
#   "'কেন, জমি কী করলাম?”",
#   '',
#   '"তুমি কী করলে আমি জানি না। আমি শুধু জানি... বাড়ির মবাইকে আমার',
#   "অসহ্য লাগছে।'”",
#   '',
#   'রেহানা মুখ কালো করে মেয়ের ঘর থেকে বের হয়ে এলেন। নিজের শোবার ঘরে',
#   'ঢুকে চমকে গেলেন। কারণ, অন্তরার বাবা এখনো জেগে আছে। তারচেয়ে বড় কথা',
#   'তার সামনে কাফনের কাপড় বিছানো। কাপড়টা প্যাকেট থেকে বের করা হয়েছে।',
#   'রেহানা বললেন, জেগে আছ কেনঃ',
#   '',
#   'মফিজউদ্দিন বিড়বিড় করে বললেন, ঘুম আসছে না।',
#   '',
#   "'সামনে কাপড় নিয়ে বসে আছ কেনঃ'",
#   '',
#   "'মেপে দেখলাম। মনে হচ্ছে কাপড় একটু শর্ট পড়বে।'",
#   '',
#   "'মাপলে কীভাবে! বাজার থেকে গজফিতাও নিয়ে এসেছা'",
#   '',
#   "'হাত দিয়ে মাপলাম। তিন হাত হচ্ছে এক গজ।'",
#   '',
#   'রেহানা স্বামীর সামনে বসতে বসতে বললেন, তোমার কী হয়েছে ঠিকমতো',
#   'বল তো।',
#   '',
#   "'কিছু হয় নাই।'",
#   '',
#   "'জবশ্যই হয়েছে। তোমার চোখ-মুখ দেখেই বোঝা যাচ্ছে কিছু একটা হয়েছে।",
#   "কাফনের কাপড় কেন কিনলে বল?'",
#   '',
#   "'কাজ আগিয়ে রাখলাম। যেদিন মারা যাব সেদিন যদি হরতাল থাকে দোকানপাট",
#   "থাকবে বন্ধ ।'",
#   '"কবরের গর্তও খুঁড়িয়ে রাখ। হরতালের দিন কবর খোদার লোক যদি না পাওয়া',
#   'যায়!”',
#   '',
#   'মফিজউদ্দিন কিছু বললেন না৷ রেহানা বললেন, আস ঘুমাতে আস। আর',
#   'খবরদার তুমি এই কাপড়ে হাত দেবে না।',
#   '',
#   '"জাচ্ছা।\'\'',
#   '',
#   "'এই কাপড়ের প্রসঙ্গ মুখেও আনবে না।'",
#   '',
#   "'আচ্ছা।'",
#   '',
#   'রেহানা স্বামীকে নিয়ে ঘুমাতে গেলেন। ইচ্ছা কবে আজ ঘনিষ্ঠ হলেন। স্বামীর',
#   'গায়ে হাত রেখে দূরে গলায় বললেন-এত রাত পর্যন্ত জেগে আছ এরকম তো',
#   'কখনো হয় না। বিশেষ কিছুর প্রয়োজন থাকলে বল। লজ্জা করার দরকার নেই । কিছু',
#   'লাগবে?',
#   '',
#   "'না।'",
#   '\x0c'],
#  ['পে',
#   "কী গল্ঃ'",
#   '',
#   "'যা ইচ্ছা বল। আজকে যে ছবিটা দেখলে সেই গল্প বলতে পার। অফিসের গল্প",
#   "বলতে পার। তোমাদের অফিসে মজ্বার কিছু হয় না?'",
#   '',
#   'ঝা!',
#   '',
#   "'কোনো গল্প করতে ইচ্ছা করছে না?'",
#   '',
#   'মফিলজউদ্দিন ক্ষাণ স্বরে বললেন, একটা গল্প করতে ইচ্ছা করছে কিন্তু তুমি রাগ',
#   'করবে।',
#   '',
#   "“না রাগ করব না, বল।'",
#   '',
#   "'কাফনের কাপড় নিয়ে গল্প। পুরুষদের কাফনের কাপড় লাগে তিনটা। এদের",
#   'আলাদা আলাদা নাম আছে। একটা হল পিরহান। ঘাড় থেকে হাটু পর্যন্ত লম্বা।',
#   'আবেকটাকে বলে ইজার।৷ মাথা থেকে পা পযন্ত ইজার দিয়ে ঢাকা হয়। আরেকটাকে',
#   "বলে লেফাফা। এটা ইজারের মতোই ৷ ভুনছ?'",
#   '',
#   "'ঠ্যা শুনছি।'",
#   '',
#   "'মেয়েদের কাপড় লাগে পাচটা। পিরহান, ইজার, লেফাফা তো আছেই, তার",
#   'ওপর বাড়তি হল-_ছের বন্দ। ছের বন্দ দিয়ে মাথার চুল জড়িয়ে দিতে হয়। আর হল',
#   "সিনা বন্দ। সিনা বন্দ দিয়ে বুক থেকে উরু পর্যন্ত ঢাকা হয়।'",
#   '',
#   'রেহানা থমথমে গলায় বললেন, আরো কিছু বলবে? মফিজউদ্দিন বললেন,',
#   'কাফনের কাপড়ের আরেকটা মজার ব্যাপার আছে। হিজড়াদের মেয়েদের মতো',
#   'কাফনের কাপড় পরাতে হয়। ওদেরও পাচ টুকরা কাপড় লাগে৷ ৰ',
#   '',
#   'বা ্\u200c',
#   '',
#   "'আর পুরুষত্ব নেই পুরুষ, যারা নপুংসক তাদের জন্যেও পাচটা কাপড় লাগে।'",
#   '',
#   "'যথেষ্ট কথা বলেছ। আর না এখন ঘুমাতে যাও।'",
#   '',
#   "'ঘুম আসছে না।'",
#   '',
#   "'ছঘুম না আসলে বারান্দায় ইাটাইাটি কর। কিংবা ছবি দেখ। অস্তরাকে বল",
#   "ভিসিআর ছেড়ে দেবে।'",
#   '',
#   "'ভিসিআর আমি নিজেই ছাড়তে পারি।'",
#   '',
#   "'তা হলে তো ভালোই ।'",
#   '',
#   'মফিজউদ্দিন বিছানা থেকে নেমে পড়লেন। রেহানাও নামলেন--_তার মাথা চড়ে',
#   'গেছে। ঘুমের ওষুধ খেয়ে ঘুমাতে হবে। ছুমের ওষুধ খেলেও হয়তো ছুম হবে না।',
#   '',
#   'রাত বারটা বাজে । অন্তরা টেলিফোন করল। একটা রিং হতেই ওপাশ থেকে',
#   'রিসিভার তুলল। অন্তরা বলল, ঘুমিয়ে পড়েছিলে?',
#   '\x0c'],
#  ["'মুমাব মানে? তুমি এমন খট করে টেলিফোন রেখে দিলে ।'",
#   '',
#   '"তুমি অসভ্য কথা বলবে আর আমি টেলিফোন ধরে থাকব। আমি এরকম মেয়েই',
#   'না। এই শোন আমার না মনটা খুব খারাপ।*',
#   '',
#   '"কেন?',
#   '',
#   "'মার সঙ্গে খারাপ ব্যবহার করেছি এই জন্যে মন খারাপ।'",
#   '',
#   "খারাপ ব্যবহার করেছ কেন? উনি কী করেছিলেন।?'",
#   '',
#   "আমার সঙ্গে গম করতে এসেছিল ।'",
#   '',
#   "'গল্প করতে এলে খারাপ ব্যবহার করবে কেন?'",
#   '',
#   'মাকে তো তুমি চেন না। মা বিরাট গলজ্বাজ। একবার গল্প শুরু করলে আর',
#   "থামবে না। গল্প কবেই যাবে।'",
#   '',
#   '\'তাতে অসুবিধা কী? তুমি গল্প করতে।"',
#   '',
#   '"মার সঙ্গে গল্প করলে আমি তোমার সঙ্গে কখন গল্ধ করব? এখন একটা কথা',
#   "আমার বলতে ইচ্ছা করছে কিন্তু বললে তুমি মাথায় উঠে যাবে। এই জন্যে বলব না।'",
#   '',
#   "'প্রিজ বল।'",
#   '',
#   "'কথাটা হচ্ছে- তুমি ছাড়া আর কারো সঙ্গে আমার কথা বলতে ভালো লাগে না।'",
#   '',
#   'মিথ্যা কথা।”',
#   '',
#   'অস্তবা কাদো কাদো গলায় বলল, তুমি আমার কথা বিশ্বাস করলে না?',
#   '',
#   'ওপাশ থেকে সঙ্গে সঙ্গে বলা হল, বিশ্বাস করি। বিশ্বাস করব না কেনঃ',
#   '',
#   "'তা হলে কেন বললে-_মিথ্যা কথা।'",
#   '',
#   "'এমনি বললাম, মজা করার জন্যে বললাম।'",
#   '',
#   "খবরদার আর বলবে না।'",
#   '',
#   "*জাচ্ছা যাও আর বলব না।'",
#   '',
#   'প্রমিজ!',
#   '',
#   "'প্রমিজ।'",
#   '',
#   '\'একটু ধর তো এক মিনিট।"',
#   '',
#   "'কোথায় যাচ্ছ?”",
#   '',
#   "'বসার ঘরে ভিসিআর চলছে। দেখে আসি কী ব্যাপার।'",
#   '',
#   "'এত রাতে কে ছবি দেখছো'",
#   '',
#   "'সেটাই তো বুঝতে পারছি না, তুমি ধর তো।'",
#   '',
#   'অন্তরা বসার ঘরে ঢুকল। স্মিত হয়ে তাকিয়ে রইল। মফিতাউদ্দিন সাহেব',
#   'ভিসিআর দেখছেন। তার গায়ে কাফনের কাপড়। তিনি শুয়ে আছেন লক্মা হয়ে। মাথার',
#   'নিচে বালিশ দেয়া যাতে ভিসিআর দেখতে অসুবিধা না হয়। অন্তরা কাপা গলায় ডাকল,',
#   'বাবা!',
#   '\x0c'],
#  ['মফিজউদ্দিন মেয়ের দিকে এক পলক তাকিয়েই টিভি পরদার দিকে দৃষ্টি ফিরিয়ে',
#   'নিলেন।',
#   '',
#   'অস্তরা বলল, তুমি কী পরে আছ বাবা?',
#   '',
#   'মফিজউদ্দিন টিভি পরদা থেকে দৃষ্টি না ফিরিয়েই বললেন--কাপড়টা পরে',
#   'দেখলাম ফিটিং হয় কি না। ভালো ফিটিং হয়েছে।',
#   '',
#   'অস্তরা সারা বাড়ি কাপিয়ে বিকট চিতকার দিল। গলা ফাটিয়ে ডাকল, মা...মা...।',
#   '',
#   'মফিজউদ্দিন সাহেবের তাতে কোনো ভাবাস্তর হল না।',
#   '',
#   'কাফনে মোড়া একজন মানুষ, শুধু মুখটা বের হয়ে আছে। চোখ খোলা। সেই',
#   'চোখ তাকিয়ে আছে টিভি পরদার দিকে। টিভি পরদার আলো এসে চোখে পড়েছে।',
#   'তার চোখ চকচক করছে।',
#   '\x0c'],
#  ['লিপি',
#   '',
#   "'জাংক মেইল' বলে একটা ব্যাপার আছে যা চরিত্রগত দিক দিয়ে ১০০ ভাগ",
#   'আমেরিকান। একমাত্র আমেরিকাতেই মেইল বক্স খুললে হাতভরতি চিঠিপত্র পাওয়া',
#   'যায়। যার ভেতর একটা বা দুটা কাজের চিঠি, বাকি সবই অকাজের বা আমেরিকান',
#   'ভাষায়-_জাংক মেইল ৷',
#   '',
#   'জাংক চিঠিগুলি চট করে আলাদা করাও মুশকিল। খাম দেখে মনে হবে খুব জরুরি',
#   'কে',
#   '',
#   'রুমান,',
#   '',
#   'তুমি কি জান তৃমি একজন অত্াভ সৌতাগ্াবান ব্যক্তি? টেলিফোন',
#   'ডাইরেষ্টরি থেকে এক মিলিয়ন র্যানডম নাষার নিয়ে একটি সুইগপঞ্টেক করা',
#   'হয়েছে। যার বিশ জন ফাইন্যালিপ্টের মধ্যে তৃমি এক জন ৷ এথম পুরক্কার',
#   'এক সঙাহ বিশ্বত্রমণের জন্য ২টি গথম শ্রেণীর বিমানের টিকিট। দিতীয়',
#   '',
#   'একটি করে গোড়া কিনতে হবে। আমরা ক্যাটালগ পাঠালাম ৷ তৃমি কোনটি',
#   'কিনতে চাও তাতে টিক মাক দিয়ে সেই পরিমাণ ডলার আমাদের ঠিকানায়',
#   '',
#   'পাঠিয়ে দেবে।',
#   'আশা করি তুমি এই সুযোগ হারাবে না। তোমাকে সুইপস্ট্রেকের',
#   'ফাইন্যালিস্টদের এক জন হবার জন্য আআঙ্তরিক ধন্যবাদ ৷',
#   '',
#   'পপ লগ',
#   'কেন জানি স্কুব আগহ নিয়ে প্রতিটি চিঠি শেষ পর্যন্ত পড়ি। যা বলে তা বিশ্বাসও করি।',
#   'আমেরিকানরা চিঠি লিখে মিথ্যা কথা বলবে এটা ভাবতেও আমার কাছে খারাপ লাগে।',
#   '\x0c'],
#  ['এই গল্পটি জাংক মেইল নিয়ে। প্রস্তাবনা অংশ শেষ হয়েছে, এখন মূল গল্পে আসি।',
#   '',
#   '১৯৮০ সনের জুন-জুলাই মাসের ঘটনা। আমি তখন নর্ণথডেকোটায়। স্টেট',
#   'পড়াশোনা করছি। হঠাৎ একদিন মেইল বক্সে একটা চিঠি পেলাম।',
#   'চিঠিটা এ রকম.',
#   'ড. আহমেদ,',
#   'জামি জেনেছি তুমি লুঙ এাচীন ভাষার বিষয়ে একজন বিশেষজ্ঞ! আমার',
#   'কাছে লুঙ ভাষায় লেখা একটি কাগজ আছে। তুমি যদি ভাষার পাঠোষঙারে',
#   'আমাকে সাহায্য কর জামি ছুশি হব। তৃমি দয়া করে নিয়ালিথিত পোস্ট বস',
#   'নাহারে জামার সঙ্গে যোগাযোগ কর। ভালো কথা, তোমার পরিশুমের জন্য',
#   'যথাযোগা পারিশ্রমিক দেয়া হবে।',
#   '',
#   'বলাই বাঙল্য, এটা একটা জাক চিঠি। পোস্ট বক্সের ঠিকানায় উত্তর নিলেই ধরা',
#   'খেতে হবে। প্রাচীন ভাষাবিষয়ক কোনো সোসাইটির সদস্য হতে হবে যার জন্য',
#   'মাসিক চাদা বিশ ডলার বা এই জাতীয় কিছু। চিঠি আমি ফেলেই দিতাম কিন্তু আমার',
#   'নামের আগে ড. পদবিটি আমাকে ধাধায় ফেলে দিল। তখনো ডষ্টর ডিমি পাই নি।',
#   'পাব পাব ভাব। কিউমিলিটিভ একজাম পাস করেছি। থিসিস লিখছি। এই সময় কেউ',
#   '০০১০০১৬৬৬০২০১২০৬২০০১৬১৬০ ১১ ৮',
#   'লিখলাম-_',
#   '',
#   'আপনার চিঠি পেয়েছি। এাচীন লুঙ ভাষা সম্পর্কে আমি কিছুই জানি না।',
#   '',
#   'আমার পড়াশোনার বিষয় পলিমার রসায়ন। আপনাকে সাহায্য করতে পারছ',
#   '',
#   'না বলে দুঃখিত! আমি খাচীন ভাষা জানি এই তথ্য কোথায় পেলেন জানালে',
#   'যুণি হব।',
#   '',
#   'বিনীত',
#   '',
#   'হুমাহূন আহমেদ',
#   '',
#   'পুনশ্চ ১ : আমি এখনো ৭. . ডিগ্রি পাই নি। আপনার এই তথ্যটিও তুল ৷',
#   'পুনশ্চ ২ : আপনার চিঠিটি যদি জাংক মেইল জাতীয় হয় তা হলে জবাব',
#   'দিবেন না।',
#   '',
#   'আনি এই চিঠির জবাব আশা করি দি। কিছু সা দিনের মাথার অব্য গেলাম।',
#   '" জবাবটা ইবই তুলে দিলাম-_-',
#   '\x0c'],
#  ['থ্রিয় আহমেদ,',
#   '',
#   'জামার চিঠিটি জাংক মেইল নয়। সে কারণেই জবাব দিচ্ছি। তৃমি',
#   'এাচীন লু ভাষা নিয়ে গবেষণা ফর এই তথা তোমার বিশ্ববিদ্যালয়ের',
#   'লাইবোরীয়ান আমাকে জানিয়েছে!',
#   '',
#   'জামি আমেরিকার খায় সব বড় লাইব্রেরিকে একটি আবেদন',
#   'পাঠয়েছিলাম। সেখানে জানতে চেয়েছি লাইব্রেরির পাঠকদের মাকে এমন',
#   'কেউ কি আছেন যারা প্রাচীন ভাষা নিয়ে পড়াশোনা বা গবেষণা করেন?',
#   '',
#   'তোমার বিশ্ববিদ্যালয়ের লাইব্রেরি তোমার নাম পাঠিয়েছে এবং তোমার',
#   'ন্যমের আগে ড. পদবি তারাই দিয়ে দিয়েছে।',
#   '',
#   'তুমি দিখেছ তোমার বিষয় পলিমার রসায়ন। আমার কেন জানি মনে',
#   'হচ্ছে পলীমার রসায়ন তোমার বিষয় হলেও তুমি লুঙ প্রাচীন ভাষা বিষয়ে',
#   'আধথহী। তা না হলে তামি আমার চিঠির জবাব দিতে না! তৃমি কি দয়া করে',
#   'একটি এাচীন ভাষা উদ্ধারে আমাকে সাহায্য করবে? লিপিটির পাঠোদ্ধার',
#   'করা আমার খুবই এয়োজন ৷',
#   '',
#   'বিনীত',
#   '',
#   'এরিথ স্যামসন',
#   'সিনোসিটা।',
#   '',
#   'বিশ্ববিদ্যালয়ের লাইব্রেরি আমার নাম কেন পাঠিয়েছে ভেবে বের করতে গিয়ে',
#   'মনে পড়ল--গত সামারে লাইব্রেরি থেকে রোসেটা স্টোনের উপর একটি বই আমি ইস্যু',
#   'করেছিলাম।',
#   '',
#   'প্রাচীন মিশরীয় হিরোলোধাফির পাঠোস্কারে রোসেটা স্টোন বিরাট ভূমিকা বেখেছিল।',
#   "ঘটনাটা কী জানার জন্য বইটি পড়া। বইটি পড়ে আরেকটি বই ইস্যু করি 'অশোকের",
#   "শিলালিপি'। 'অশোকের শিলালিপি' অনেক দিন ধরে পাঠোষ্ধার করা যাচ্ছিল না এক",
#   'ইংরেজ সাহেব শিলালিপির পাঠোস্কার করেন। এই দুটি বই পড়ার পর আমি মায়াদের',
#   'ভাষা পাঠোদ্কারের চেষ্টাবিষয়ক আরেকটি বই ইস্যু করি। এই থেকেই কি আমাদের',
#   'বিশ্ববিদ্যালয়ের লাইব্রেরিয়ানের ধারণা হয়েছে আমি প্রাচীন ভাষার একজন গবেষক?',
#   '',
#   'আমি যদি প্রাচীন ভাষার গবেষক হইও বিশ্ববিদ্যালয়ের লাইক্তেরিয়ান',
#   'আমার অনুমতি ছাড়া আমার নাম-ঠিকানা কাউকে দিতে পারে না। এইসব বিষয়ে',
#   'আমেরিকায় নিয়মকানুন খুব কঠিন। আমি ঠিক করলাম লাইব্রেরিয়ানকে ব্যাপারটা',
#   'জিঙ্সেস করব।',
#   '',
#   'জিজ্ঞেস করা হল না। কারণ আমি তখন খুবই ব্যস্ত। মানুষ তার এক জীবনে',
#   'নানান ধরনের ব্যস্ততায় জড়িয়ে যায়। পিএইচ.ডি. থিসিস প্রস্তুতকালীন ব্যস্ততার সঙ্গে',
#   '\x0c'],
#  ['অন্য কোনো ব্যস্ততার তুলনা চলে বলে আমি মনে করি না। একটা চ্যান্টার লিখে',
#   'প্রফেসরকে দেখাই, তিনি পুরোটা কেটে দেন। আবার লিখে নিয়ে যাই, আবারো কেটে',
#   'দেন। আমি ল্যাবরেটরি রেজাল্টের যে ব্যাখ্যা দেই সেগুলি তার পছন্দ হয় না। তিনি',
#   'যেসব ব্যাখ্যা দেন তা আমার পছন্দ হয় না। চলতে থাকে ধারাবাহিক কাটাকুটি খেলা।',
#   '',
#   'মাঝে মাঝে রাগারাগিও হয়। যেমন, একদিন আমার প্রফেসর বললেন-_',
#   "'আহমেদ, তোমাকে তো বেশ বুদ্ধিমান মানুষ হিসেবেই জানতাম়। এখন তোমার",
#   'থিসিস পড়তে গিয়ে মনে হচ্ছে তোমার আই কিউ এবং মিডিয়াম সাইজের কড মাছের',
#   "আই কিউ কাছাকাছি। মাছেরটা বরং কিছু বেশি হতে পারে।'",
#   '',
#   'প্রফেসরের এই ধরনের কথাবার্তায় খুবই মন খারাপ হয়। এপার্টমেন্টে ফিরে স্ত্রীর',
#   'সঙ্গে ঝগড়া করি। ভাত না খেয়ে থালা-বাসন ছুড়ে মারি। থিসিস লেখার সময়',
#   'পিএইচ.ডি. স্টুডেন্টদের এই আচরণ খুবই স্বাভাবিক। আমেরিকার ব্যুরো অফ',
#   'স্ট্যাটিসটিকসের এই বিষয়ে একটি স্ট্যাটিসটিকসও আছে। তারা দেখিয়েছে- বিবাহিত',
#   'ছাত্রদের মধ্যে বিবাহবিচ্ছেদের হার পিএইচ.ডি. করার সময়ে সবচে বেশি- শতকরা',
#   '৫৩। এই ৫৩-এর ভেতর ৯৭% বিবাহবিচ্ছেদ ঘটে যখন ছাত্ররা তাদের থিসিস লেখা',
#   'শুরু করে।',
#   '',
#   'প্রতিদিন যে হারে স্ত্রীর সঙ্গে ঝগড়া হচ্ছে তাতে মনে হয় আমি ওই স্টেজে দ্রুত',
#   'চলে এসেছি। একদিন ঝগড়া চরমে উঠল- আমার কন্যার মাতা আমাকে হতভম্ব করে',
#   'কন্যার হাত ধরে এয়ারপোর্টের দিকে রওনা হল। সে নাকি নিউইয়র্কের দুটো টিকিট',
#   'কাটিয়ে রেখেছে। আসছে দু মাস সে নিউইয়র্কে তার মামার কাছে থাকবে। আমার',
#   'থিসিস লেখা শেষ হবার পর ফিরবে ৷ যদি কোনো কারণে খিসিস লেখা শেষ না হয় তা',
#   'হলে আর ফিরবে না।',
#   '',
#   'আমি রাগ দেখিয়ে বললাম, খুবই ভালো কথা। তোমাদের আরো আগেই যাওয়া',
#   'উচিত ছিল৷ হু কেয়ারস? গো টু হেল।',
#   '',
#   "'পগো টু হেল' গালিটা তখন নতুন শিখেছি। যখন-তখন ব্যবহার করি এবং অত্যন্ত",
#   "তালো লাগে। বাঙলা ভাষায় 'জাহান্নামে যাও'-এর চেয়েও লাগসই মনে হয়।",
#   '',
#   'ব্যাচেলার জীবন হচ্ছে সর্বোত্তম। এই জীবনে আছে মুক্তির আনন্দ- এ ধরনের',
#   'অতি উচ্চ ভাব নিয়ে প্রথম রাতটা কাটল। দ্বিতীয় রাত আর কাটতে চায় না। আমি',
#   'সময় কাটাবার জন্য রাত এগারটায় এরিখ স্যামসনকে টেলিফোন করলাম।',
#   '',
#   "'হ্যালো এরিখ।'",
#   '',
#   "'ইয়েস। মে আই নো, হ ইজ স্পিকিং",
#   '',
#   'আমি নাম বললাম। আমার মনে হল অপর প্রান্তে এরিখ আনন্দের আতিশয্যে শূন্যে',
#   'লাফ দিল। যেন দীর্ঘদিনের অদর্শনের পর হারানো বন্ধুকে ফিরে পেয়েছে। উচ্ছ্বাস বাধ',
#   'মানছে না। আমেরিকানদের এ ধরনের উচ্ছ্বাসের সবটাই সাধারণত মেকি হয়ে থাকে।',
#   '\x0c'],
#  ['আমার মতো বোকা বিদেশীরা এতে বিভ্রাস্ত হয়। যাই হোক আমাদের মধ্যে কথাবার্তা',
#   'যা হল তা মোটামুটি এরকম-_',
#   '',
#   "'আহমেদ তুমি কেমন আছ?”",
#   '',
#   "'খুবই ভালো আছি। তবে এই মুহূর্তে মনটা একটু খারাপ ।'",
#   '',
#   '*কেন জানতে পারি কি? যদি কোনো অসুবিধা না থাকে।”',
#   '',
#   "'কোনো অসুবিধা নেই। রাগ করে আমার স্ত্রী নিউইয়র্কে চলে গেছে। যাবার",
#   "আগে জানিয়েছে দু মাসের ভেতর সে ফিরবে না।'",
#   '',
#   "'তুমি নিশ্চিত থাক দিন তিনেকের ডেতরই তোমার স্ত্রী ফিরে আসবে। মন",
#   "খারাপের কারণেই তুমি আমাকে টেলিফোন করেছ নাকি অন্য কোনো কারণ আছে?'",
#   '',
#   "*তোমার প্রাচীন লিপির পাঠোস্ধারের কিছু হয়েছে কি না জানার আহ হচ্ছে।'",
#   '',
#   "'এখনো কিছু হয় নি।'",
#   '',
#   "'চেষ্টা নিশ্চয়ই চালিয়ে যাচ্ছ?'",
#   '',
#   "'সাদ্কেতিক কোড ভাঙতে পাবে এমন একটা সফটওয়্যারের সন্ধান পেয়েছি। দাম",
#   'ধরাছোয়ার বাইরে বলে কিনতে পারছি না। তবে মনে হয় কিনে ফেলব। তোমার কি',
#   "ধারণা কেনা উচিত?'",
#   '',
#   "'তুমি যদি পুরোপুরি নিশ্চিত হও যে সফটওয়্যার তোমার লিপির পাঠোল্কার করবে",
#   'তা হলে কিনে ফেল। আর যদি সন্দেহ থাকে তা হলে কেনা ঠিক হবে না। কারণ এই',
#   "সফটওয়্যারের তখন আর কোনো উপযোগিতা নেই।'",
#   '',
#   '“আমিও তাই ভাবছি। তোমাকে তোমার মূল্যবান মতামতের জন্য অসংখ্য',
#   'খন্যবাদ।”',
#   '',
#   'এই পর্যন্ত কথাবার্তার পর আমি টেলিফোন রেখে সুমাতে গেলাম। তার পাচ',
#   'মিনিটের মাথায় এরিখের টেলিফোন পেলাম।',
#   '',
#   'হ্যালো আহমেদ ।”',
#   '',
#   "'হ্যা বল।'",
#   '',
#   '*তোমাকে একটা কথা বলতে ভুলে গিয়েছি বলে দুঃখিত। কথাটা হচ্ছে আমি',
#   'সিয়াটলে যাব। ফার্গো সিটি পার হয়ে যেতে হবে। তোমার হাতে যদি অবসর থাকে',
#   'তা হলে ভাবছি এক রাত থাকব ফার্গো সিটিতে। তোমার সঙ্গে গল্প করা হবে এবং',
#   "তুমি প্রাচীন লিপিটা ইচ্ছা করলে দেখতেও পার।'",
#   '',
#   'আমি বললাম, প্রাচীন লিপি দেখার জন্য আমি ছটফট করছি।',
#   '',
#   'কথাটা আমেরিকানদের মতো বললাম। আমেরিকানরা অতিরিক্ত উৎসাহ',
#   'দেখানোটা ভদ্রতার অংশ বলে মনে করে। কোনো আমেরিকান মা যদি বলে আমার',
#   'বাচ্চাটা এবারে ভালো শ্রেড পেয়েছে তখন যাকে এই কথাটা বলা হবে তার দায়িত্ব',
#   'হবে বিকট চিতকার দিয়ে বলা-_“ওয়ান্ডারফুল ৷ হোয়াট এ প্লট নিউজ!”',
#   '\x0c'],
#  ['সত্যি কথাটা হল প্রাচীন লিপি বিষয়ে আমার তেমন গ্রহ নেই। আজ পর্যন্ত এমন',
#   'কোনো প্রাচীন লিপি পাওয়া যায় নি যেখানে রাজাদের যুদ্ধজ্য়ের কাহিনী এবং',
#   'পুরোহিতদের মন্ত্র ছাড়া অন্য কিছু লেখা রাজাবাদশা এবং পুরোহিতদের বিষয়ে আগ্রহী',
#   'হ্বার কোনো কারণ থাকার কথা না।',
#   '',
#   'এরিখ স্যামসনের সঙ্গে ফার্গো হোটেলে দেখা হল। তার গলার স্বর শুনে মনে',
#   'হয়েছিল যুবক মানুষ। এখন দেখি প্রৌঢ় । আমেরিকান প্রৌঢ়দের বয়স বোঝা মুশকিল,',
#   '৫০ থেকে ৭০ হতে পারে। বেশিও হতে পারে।',
#   '',
#   'সে আমাকে জড়িয়ে ধরে আমেরিকান কায়দায় অনেক উচ্ছ্বাস প্রকাশ করল।',
#   'গিফট র্যাপে মুড়ে সে আমার জন্য একটা গিফটও নিয়ে এসেছে। আমি সেই গিফট',
#   'নিলাম। চামড়ায় বাধানো ভায়েরি। আমি সেই গিফট হাতে নিয়ে আমেরিকান কায়দায়',
#   'অনেক উচ্ছ্বাস প্রকাশ করলাম। এ রকম একটা ডায়েরি আমি অনেকদিন ধরে',
#   'খুজছিলাম। কয়েকবার দোকানে দেখেছি-_কিন্তু কেন জানি শেষ পর্যন্ত কেনা হয় নি।',
#   'এ ধরনের রুটিন কথাবার্তা বললাম।',
#   '',
#   'আমার অতিথি সেই হিসেবে আমি তাকে রাতে আমার এপার্টমেন্টে খেতে নিয়ে',
#   'গেলাম। এবং বললাম-_তুমি খাওয়াদাওয়া কর। তারপর আমরা গল্পগুজব করব।',
#   'সবচে ডালো হয় রাতে তুমি যদি হোটেলে ফিরে না যাও। আমার এপার্টমেন্ট পুরো',
#   'থালি। তুমি রাতে থেকে যাবে। প্রয়োজনে সারারাত আমরা গল্প করতে পারব।',
#   '',
#   'বাঙালিরা হোটেল পছন্দ করে না-_তারা যেখানেই যায় বন্ধুবান্ধব খুঁজে বেড়ায়,',
#   'বন্ধুবান্ধব না পেলে দেশের মানুষ খোজে। হোটেল খোজে না। আমেরিকানদের স্বভাব',
#   'উল্টো, তারা প্রথমেই খোজে হোটেল। তারপরেও এরিখ স্যামসন আমার ঘরে থাকতে',
#   'রাজি হয়ে গেল। আমার রাধা অথাদ্য ডাল-ভাত এবং ডিম ভাজা তৃপ্তি করে খেল।',
#   'ডাল খেয়ে বলল, এত চমৎকার স্যুপ সে অনেকদিন খায় নি। তাকে যেন এই স্মুপের',
#   'রেসিপি দেয়া হয়।',
#   '',
#   'খাওয়া শেষ করে আমরা গল্প করতে গেলাম। কথক এরিখ স্যামসন, আমি',
#   'শ্রোতা। আমেরিকানরা গল্প ভালো বলতে পারে না। কিন্তু এরিখ দেখলাম ভালোই গল্প',
#   'করে। সাউথের উচ্চারণে তার ইংরেজি বুঝতে মাঝে মাঝে সমস্যা হচ্ছে। আমাকে',
#   'প্রায়ই বলতে হচ্ছে--[01০852 58) 1 88১11. তারপরেও বলতে বাধ্য হচ্ছি কোনো',
#   'আমেরিকানের মধ্যে আমি গল্প বলার এমন প্টাইল দেখি নি।',
#   '',
#   '“আহমেদ, তোমাদের পূর্বদেশীয় ভদ্রতার কথা আমি বইপত্রে পড়েছি। বাস্তবে',
#   'দেখার সুযোগ আগে হয় নি। আজ দেখলাম। তুমি আমার জন্য রান্নাবান্না করেছ।',
#   'হোটেল থেকে আমাকে নিয়ে এসেছ এবং তোমার এপার্টমেন্টে আমাকে রাতে থাকতে',
#   'বলছ- আমি খুবই আনন্দ পেয়েছি। তোমাকে অসংখ্য ধন্যবাদ। এ ধরনের আদরে',
#   '\x0c'],
#  ['আমরা আমেরিকানরা অভ্যস্ত না। আমার খানিকটা অস্বস্তি অবিশ্যি লাগছে। কিন্তু ভালো',
#   'লাগছে অনেক বেশি। যাই হোক আমি প্রাচীন লিপিবিষয়ক গল্পটা এখন তোমাকে',
#   'বলব। এবং মূল লিপিটা তোমাকে দেখাব। এই লিপি বিষয়ে আমার এত আগ্রহ কেন',
#   'তা গল্পটা শুনলেই তুমি ধরতে পারবে। এই গল্পের প্রায় সবটা জুড়েই আছে আমার স্তর',
#   'কেরোলিন। কাজেই এখন আমি যা করব তা হল কেরোলিনের গল্প বলব।',
#   '',
#   'পৃথিবীর সব দেশেই বন্ধুবান্ধবের কাছে স্ত্রীর গল করা অরুচির পর্যায়ে পড়ে।',
#   'তারপরেও বাধ্য হয়ে আমাকে তার গল্প করতে হচ্ছে।',
#   '',
#   'আমি কেরোলিনকে বিয়ে করি যখন আমার বয়স মাত্র তেইশ। আমেরিকান',
#   'পুরুষরা দুই ভাগে বিভক্ত, এক ভাগ বিয়ে করে খুব অল্প বয়সে-_-আর এক ভাগ বিয়ে',
#   'করে মধ্যবয়স পার করে। আমি প্রথম দলের।',
#   '',
#   'কেরোলিন ইউনিভার্সিটিতে আমার সঙ্গে পড়ত। আমরা ক্লাসের সব ছেলেমেয়েরা',
#   'তাকে খুব ভয়ের চোখে দেখতাম। কারণ, সে ছিল ডয়াবহ ধরনের ভালো ছাত্রী। শুধু',
#   "আমরা ছাত্রছাত্রীরা না, শিক্ষকরাও তাকে খুব সমীহের চোখে দেখতেন। 'অথচ সে ছিল",
#   'খুবই বিনয়ী। ক্লাসে এসে শেষের সারির চেয়ারের একটিতে মাথা নিচু করে বসে',
#   'থাকত। শিক্ষকরা কোনো প্রশ্ন করলে সে কখনো জবাব দেবার জন্য হাত তুলত না।',
#   'তাকেও শিক্ষকরা কথনো প্রশ্ন করতেন না, কারণ তারা ধরেই নিয়েছেন, এমন কোনো',
#   'প্রশ্ন তাকে করা যাবে না যার উত্তর তার জানা নেই।',
#   '',
#   'এ ধরনের মেয়েদের সঙ্গে আগবাড়িয়ে কেউ কথা বলে না। তাদের সঙ্গে ডেট',
#   'করা তো অকল্পনীয় ব্যাপার। কেরোলিনের প্রসঙ্গে অনেক রসিকতাও আমাদের মধ্যে',
#   'প্রচলিত ছিল। যেমন একবার নাকি বাজি ধরে কোন এক সিনিয়র ছাত্র কেরোলিনকে',
#   'ভেট-এ নিয়ে গিয়েছিল। চাইনিজ ডিনার। ডিনার শেষে স্পিলবার্গের ছবি। কেরোলিন',
#   'নাকি পুরো সময়টায় তার ডেটকে শুধু ফিলিক্সের প্রশ্ন করেছে। ডেট একবার শুধু',
#   'বলেছে--কেরোলিন তোমার চোখ তো খুব সুন্দর। কালো চোখ।',
#   '',
#   'তার উত্তরে কেরোলিন বলেছে- চোখের কালোটা হয় টিনডেল এফেতট্টের জন্যে ।',
#   'দা এ ০ --০-০০“',
#   '',
#   '1',
#   '',
#   'ডেটের শেষে ছেলেটা বাড়িতে ফিরেছে দ্র এবং প্রচণ্ড মাথাব্যথা নিয়ে',
#   '',
#   'কেরোলিনকে আমরা দূরে সরিয়ে রেখেছিলাম। আমেরিকান সোসাইটি অতি স্বার্ট',
#   'তরুণী পছন্দ করে না। স্মার্ট শব্দটি আমি মেধা অর্থে ব্যবহার করছি।',
#   '',
#   'যাই হোক, একদিন কী হয়েছে বলি। টার্ম পেপার জমা দিতে হবে-_আমি পেপার',
#   'লেখার জন্য লাইব্রেরিতে গিয়েছি। হঠাৎ দেখি লাইব্রেরির এক কোনায় কেরোলিন মাথা',
#   'নিছু করে বসে আছে। তার সামনে বেশ কিছু বই। একটা পেপার কাপে কফি।',
#   'ন্যাপকিনের উপর একটা স্যান্ডউইচ রাখা। স্যানুউটইচের পাশে একটা আগেল। তার',
#   '\x0c'],
#  ['দুপুরের খাবার। আমি কী মনে করে যেন তার পাশে দাড়িয়ে বললাম-_“হ্যালো',
#   'কেরোলিন”। সে চমকে উঠে দাড়াল। তার হাতের ধাক্কা লেগে কফির কাপ উল্টে',
#   'গেল। চারদিকে কফি ছড়িয়ে বিশ্রী অবস্থা। আমি বললাম, তোমাকে চমকে দেয়ার',
#   'জন্য দুঃখিত ৷ কেরোলিন কাপা কাপা গলায় বলল, ইটস ওকে । ইটস ওকে।',
#   '',
#   'আমি বললাম, তুমি বোধহয় আমাকে চিনতে পারছ না। তুমি তো ক্লাসে',
#   'ব্ল্যাকবোর্ড ছাড়া কোনোদিকে তাকাও না। আমি যেহেতু ব্যাকবোর্ড না, আমাকে চেনার',
#   'কথাও না।',
#   '',
#   'কেরোলিন মাথা নিচু করে বলল, আমি তোমাকে চিনি। তোমার নাম এরিখ। তুমি',
#   'গতকাল একটা নীল প্লেজার পরে ক্লাসে এসেছ। তার আগের দিন ইয়েলো স্ট্রাইপের',
#   'ফুলহাতা শার্ট পরেছ। তার আগের দিন সাদা জাম্পার...',
#   '',
#   'আমি হততম্ব হয়ে কেরোলিনের দিকে তাকালাম। নিজের বিশ্য়ের ধাক্কা একটু',
#   'সামলে নিয়ে বললাম--ক্লাসে কোন ছাত্র কী পরে আসে তা তুমি জান?',
#   '',
#   'কেরোলিন নরম গলায় বলল, জানি।',
#   '',
#   'পেপার কাপ থেকে কফি গড়িয়ে পড়ে টেবিল নষ্ট করছিল। কেরোলিন টেবিলে',
#   'রাখা বইপত্র সরাতে গিয়ে সব এলোমেলো করে দিল। তার স্যান্ডউইচ এবং আপেল',
#   'মেঝেতে পড়ে গেল। আমি বললাম, আমি খুবই দুঃখিত, তোমার লাঞ্চ নষ্ট করে',
#   'দিয়েছি। সে আগের মতো বলল, ইটস ওকে ৷ ইটস ওকে।',
#   '',
#   'আমি বললাম, যেহেতু তোমার দুপুরের খাবার আমি নষ্ট করেছি, রাতের ডিনারটা',
#   'কি আমি কিনে দিতে পারি? 01 | 85% ১০৩ ৩৮ ৪ 0৯1৫?',
#   '',
#   'কেরোলিন চুপ করে রইল। আমি বললাম- তোমার যদি অন্য কোনো পরিকল্পনা',
#   'না থাকে তা হলে এসো রাতে আমরা একসঙ্গে ডিনার করি।',
#   '',
#   'কেরোলিন হ্যা-সূচক মাথা নাড়ল।',
#   '',
#   'আমি বললাম, ঠিক সাতটায় তুমি কান্ট্রি কিচেন রেস্তরায় চলে এসো। কান্তি',
#   'কিচেন চেন তো-_সাউথ বুলেভার।',
#   '',
#   'কেরোলিন বিড়বিড় করে বলল, আমি চিনি।',
#   '',
#   '"তা হলে সন্ধ্যা সাতটায় তোমার সঙ্গে দেখা হবে।”',
#   '',
#   'আমি লাইব্রেরি থেকে চলে এলাম এবং সিঁড়ি দিয়ে নামার সময় নিজের ওপর খুব',
#   "রাগ হতে লাগল। কেন হঠাৎ মাথায় ভুত চাপল? কেন মেয়েটাকে 'ডেট'-এ নিতে",
#   'চাচ্ছি? যে মেয়ে তার ক্লাসের ছেলেমেয়েরা কে কবে কোন কাপড় পরছে তা হড়হড় করে',
#   'বলে দিতে পারে তার কাছ থেকে পাচ শ হাত দূরে থাকা দরকার। জেনেগুনে আমি এত',
#   'বড় ভুল কী করে করলাম? এমন তো না যে আমার ডেট পেতে সমস্যা হচ্ছে।',
#   '',
#   'কান্ট কিচেন রেস্তরায় আমি সাতটার সময় উপস্থিত হলাম। কোনো মেয়েকে',
#   'ডেটে ডেকে যথাসময়ে উপস্থিত না হওয়া বড় ধরনের অন্যায়। সেই অন্যায় আমি',
#   '\x0c'],
#  ['করতে পারি না। আমি ভেবেছিলাম পৌছেই দেখব কেরোলিন রেস্টুরেন্টের বাইরে',
#   'জবুখবু হয়ে খানিকটা কুঁজো ভঙ্গিতে দাড়িয়ে আছে। তার দৃষ্টি মেঝের দিকে। মেঝের',
#   'ডিজাইন জ্যামিতির কোনো সূত্রের সঙ্গে ফেলা যায় কি না তাই ভাবছে।',
#   '',
#   'ঘটনা সে রকম হল না।',
#   '',
#   'আমি কেরোলিনকে দেখে হোঁচটের মতো খেলাম। সে খুবই সেজেগুজে এসেছে।',
#   'ঠোটে গাঢ় লিপস্থটিক। সুন্দর করে চুল বাধা। লাল সার্ট এবং সবুজ টপসে তাকে লাগছে',
#   'ইন্দ্রাণীর মতো। এই মেয়ে যে সাজতে পারে এবং এতটা সেজে বেন্তরায় আসতে পাবে',
#   'আমি তা কলনাও করি নি। আমি বললাম, কেরোলিন তোমাকে খুব সুন্দর লাগছে।',
#   '',
#   'কেরোলিন লজ্জা পেয়ে হাসল।',
#   '',
#   'আমি বললাম, তোমাকে এই পোশাকটায় চমৎকার লাগছে।',
#   '',
#   'কেরোলিন ফিসফিস করে বলল-_ থ্যাংক য়্যু ৷',
#   '',
#   'ডিনার খেতে খেতে গুরুত্বপূর্ণ কিছু তথ্য জানলাম। যেমন--১. কেরোলিন বড়',
#   "হয়েছে 'হোমে'। তার বাবা-মা কে সে জানে না। ২. আজ যে পোশাক সে পরে",
#   'এসেছে ওটা আজই কেনা হয়েছে। স্কার্ট টপস এবং জুতা কিনতে লেগেছে তিন শ',
#   'এগার ডলার। ৩. আজ সে জীবনের প্রথম ডেটে এসেছে। তাকে কখনো কোনো ছেলে',
#   'ডেটে আসার জন্য নিমন্ত্রণ কবে নি। ৪. পড়াশোনা করতে তার একেবারেই ভালো',
#   'লাগে না। কিছু করার নেই বলেই সে পড়াশোনা করে। যদি কিছু করার থাকত তা',
#   "হলে অবশ্যই পড়াশোনা করত না। ৫. তার সঙ্গে আমার মতো '$010%' কোনো ছেলে",
#   'এর আগে কথা বলে নি।',
#   '',
#   'আমি অভিভূত হয়ে গেলাম। ডিনারের মাঝামাঝি এসে আমার মনে হল, এই',
#   'মেয়েটি সারাক্ষণ আমার চোখের সামনে না থাকলে আমি ঝাচব না। আমি আমার বাকি',
#   'জীবন এই মেয়েটির লাজুক মুখের দিকে তাকিয়ে কাটিয়ে দিতে পারব। আমি পুরোপুরি',
#   'ঘোরের মধ্যে চলে গেলাম। পৃথিবীর সবচে রূপবতী মেয়েটি যেন আমার সামনে বসে',
#   'আছে। যেন তাকে আমি শুধু আজ রাতের ডিনারের সময়টুকুর জন্যে পেয়েছি। ডিনার',
#   'শেষ হলে সে চলে যাবে। আর তাকে পাব না।"',
#   '',
#   'এরিথ দম নেবার জন্যে থামল। আমি বললাম, এ পৃথিবী একবার পায় তাকে,',
#   'কোনোদিন পায় নাকো আর।',
#   '',
#   'এরিখথ বলল, তার মানে?',
#   '',
#   'আমি হাসতে হাসতে বললাম, তোমার অবস্থার কথা ভেবেই হয়তো আমাদের',
#   'দেশের এক বাঙালি কবি এই লাইনগুলি লিখেছিলেন।',
#   '',
#   "'কবির নাম কীঃ'",
#   '',
#   "'কবির নাম জীবনানন্দ দাশ।'",
#   '',
#   '"তুমি অবশ্যই সেই কবিকে আমার এপ্রিসিয়েশন পৌছে দেবে।\'',
#   '\x0c'],
#  ['*তিনি জীবিত নেই। কবিতার লাইনগুলি তার জন্যেও প্রযোজ্য হয়ে গেছে।',
#   'যাই হোক তুমি গল্প শেষ কর। আমার ধারণা সেই রাতেই তুমি মেয়েটিকে প্রপোজ',
#   "ক্র্\u200c।'",
#   '',
#   "'তোমার ধারণা এক শ ভাগ সত্যি। আমেরিকান ছেলেরা মাঝেমধ্যে খুব নাটকীয়",
#   'কায়দায় প্রপোজ করে। যেমন মেয়েটির সামনে ইাটু পেড়ে মাথা নিচু করে বসে। দু',
#   'হাত মুঠো করে প্রার্থনার ভঙ্গি করে বলে-_“"আমি তোমাকে আমার জীবনসঙ্গিনী হবার',
#   'জন্যে প্রার্থনা করছি” ৷”',
#   '',
#   '"তুমি তাই করলে?\'',
#   '',
#   "“'হ্যা। ডিনার শেষ করে তাই করলাম। কেবোলিনের চোখ দিয়ে টপটপ করে পানি",
#   'পড়তে লাগল। আমাদের চারদিকে লোক জমে গেল। হাততালি পড়তে লাগল। এবং',
#   'কান্টি কিচেন রেস্তরার মালিক রবার্ট উচুগলায় বলল- এই আনন্দময় ঘটনা শ্বরণীয়',
#   'করে রাখার জন্যে কান্টি কিচেনে উপস্থিত সবাই এক গ্লাস করে ফ্লি রেডওয়াইন পাবে।',
#   "আনন্দের একটা জোয়ার শুরু হয়ে গেল।'",
#   '',
#   "*'তোমরা পরদিন বিয়ে করলে?”",
#   '',
#   "'আমেরিকায় হট করে বিয়ে করা যায় না। বিয়ের লাইসেন্স করতে হয়। সেই",
#   'লাইসেন্সের জন্যে ডাক্তারি পরীক্ষা লাগে। আমরা ঠিক এক মাস দশ দিনের মাথায়',
#   "'বিয়ে করলাম। বিয়ে মানেই বিরাট ঘটনা। আমার জন্যে তা ছিল অস্তিত্ব ভৃলিয়ে দেবার",
#   'মতো ঘটনা। আমার আনন্দের সীমা রইল না। মাঝে মাঝে ইচ্ছা করত হ্যান্ডতমাইক',
#   'নিয়ে রাস্তায় নেমে পড়ি, সবাইকে বলি-_হ্যালো হ্যালো কেরোলিন নামের মেয়েটি',
#   'আমার। শুধুই আমার। মাঝে মাঝে রাতে ঘড়িতে এ্যালার্য দিয়ে রাখতাম। ঘুম ভাঙলে',
#   'কী করতাম জান? কেরোলিনের দিকে তাকিয়ে থাকতাম। তার ঘুম ভাঙাতাম না।',
#   'শওধুমাত্র তার দিকে তাকিয়ে থাকার জন্যে জেগে থাকতাম। আমার পাগলামির গল্প',
#   'কেমন লাগছে?”',
#   '',
#   "'ভালো লাগছে। কেরোলিনকে দেখতে ইচ্ছা করছে।'",
#   '',
#   "'আমার কাছে তার ছবি আছে। গল্পটা শেষ হোক তোমাকে দেখাব ।'",
#   '',
#   "'থ্যাক য়্য।'",
#   '',
#   "'আমার পাগলামি দেখে কেরোলিন খুব হাসলেও সে নিজেও কিছু কম পাগলামি",
#   'করে নি। যেমন ধর সে ইউনিভার্সিটি ছেড়ে দিল। তার মতো ছাত্রী পড়াশোনা ছাড়তে',
#   'পারে এটা ভাবাই যায় না। তার যুক্তি হচ্ছে পড়াশোনা চালিয়ে গেলে সে আমার দিকে',
#   'নজর দিতে পারবে না। এটা তার পক্ষে সম্ভব না। তার -কাছে আমি ছাড়া পৃথিবীর',
#   'সবকিছুই গুরুত্বহীন। তার বিষয়ে খুব মজার ব্যাপার আছে। সেটা বলছি। প্রিজ',
#   'হাসতে পারবে না৷”',
#   '',
#   '"তুমি নিশ্চিত থাক আমি হাসব না।\'',
#   '\x0c'],
#  ['*ও ঘুমাত খুব অদ্ভুত ভঙ্গিতে । সে তার পা দিয়ে আমার পা পেঁচিয়ে একটা গিটুর',
#   "মতো করে ফেলত। হা-হা-হা।'",
#   '',
#   "'মজার তো।'",
#   '',
#   '*\'আমি তার নাম দিয়েছিলাম [11633 1004."',
#   'বাধা ভাষায় এটা হবে “গিট কুমারী”। তোমার কথা শুনে মনে হচ্ছে-_তোমরা',
#   'আমেরিকার সবচে সুখী দম্পতি ৷*',
#   '',
#   "'শুধু আমেরিকায় বলছ কেন? আমরা ছিলাম এই পৃথিবীর সবচে সুখী স্বামী-স্ত্রী ।'",
#   '',
#   "ছিলাম মানে? কেরোলিন কোথায়?'",
#   '',
#   '"বিয়ের দু বছরের মাথায় সে মারা যায়।”',
#   '',
#   "'আই জ্যাম সরি।”",
#   '',
#   '“বিয়ের এক বছর আট মাসের দিন তার ক্যান্সার ধরা পড়ে। থারাপ ধরনের',
#   'রায়ূতন্ত্রের ক্যা্সার। কী কষ্ট যে সে করেছে তা তুমি কল্পনাও করতে পারবে না!',
#   'শেষের দিকে এমন হল আমি চার্চে গিয়ে বলতে বাধ্য হলাম, “হে ঈশ্বর তুমি',
#   'কেরোলিনের প্রতি করুণা কর। যেখান থেকে সে এই পৃথিবীতে এসেছে তাকে সেখানে',
#   'নিয়ে যাও। রোগযন্ত্রণা থেকে তাকে মুক্তি দাও।” রোগটা তার মস্তিষ্কে ছড়িয়ে গেল।',
#   'সে কাউকে চিনতে পারত না। আমাকেও না। তার কাছে গিয়ে কেরোলিন কেরোলিন',
#   'বলে ডাকলে সে শুধু চোখ তুলে তাকাত, সেই দৃষ্টিতে পরিচয়ের আতাস মাত্র থাকত',
#   'না।”',
#   '',
#   'এরিখ দীর্ঘনিশ্বাস ফেলে বলল, আহমেদ আমার গল্প শেষ হয়েছে। এখন ভালো',
#   'করে কফি বানাও। কফি খেয়ে শুয়ে পড়ব। ঘুম পাচ্ছে।',
#   '',
#   'আমি বললাম, লুপ্ত প্রাচীন লিপির ব্যাপারটা কিন্তু এখনো আসে নি।',
#   '',
#   'এরিখ বলল, যে লিপির কথা বলছি ওটা কেরোলিনের লেখা। দুদিন আগে',
#   'ইশারায় জানাল সে কিছু লিখতে চায়। আমি তাকে কাগজ-কলম ৷ সে সারা',
#   'দিন শুয়ে শুয়ে লিখল। সন্ধ্যাবেলা লেখা শেষ হল। আমাকে লেখা কাগজটা দিয়ে',
#   'কোথায় চলে গেল। তার দুদিন পর তার মৃত্যু হয।',
#   '',
#   "'সাদ্ধেতিক ভাষায় লেখা কোনো চিঠি?'",
#   '',
#   "্যা।'",
#   '',
#   "'সাদ্ধেতিক ভাষায় লেখার দরকার পড়ল কেন?'",
#   '',
#   "'আহমেদ সে-ই তো আমি বলতে পারব না। ক্যান্সারের আক্রমণে তার মস্তিষ্ক",
#   'এফেকটেড হয়েছিল তার কারণে হতে পারে। কিছবা অন্য কিছুও হতে পারে। লিপির',
#   'পাঠোদ্ধার করা গেলেই ব্যাপারটা জানা যাবে। কিংবা এমনও হতে পারে যে এটা',
#   'আসলে কোনো লিপিটিপি নয়। কাগজে আকাবুকি কাটা। কেরোলিন আমাকে দিয়ে',
#   'গেছে যেন এই লেখার রহস্য উদ্ধার করতে গিয়ে আমার জীবন কেটে যায়। আমি',
#   '\x0c'],
#  ['তাকে হারানোর কষ্ট ভুলে থাকতে পারি। কেরোলিন মারা গেছে একুশ বছর আগে।',
#   'এই একুশ বছর ধরে আমি চিঠিটার রহস্য উদ্ধার করার চেষ্টা করছি। মানুষ ক্লান্ত হয়,',
#   "আমি ক্লান্ত হই না। কেন ক্লান্ত হই না বল তো?'",
#   '',
#   "'বলতে পারছি না।'",
#   '',
#   "'ক্লাস্ত হই না। কারণ, আমার মনে হয় কেরোলিন একটু দূরে দাড়িয়ে লাজুক",
#   'ভঙ্গিতে হাসতে হাসতে আমার দিকে তাকিয়ে আছে। দেখছে আমি তার রহস্য ভাঙার',
#   "চেষ্টা করছি কি না। হাল ছেড়ে দিচ্ছি কি না।'",
#   '',
#   '“তুমি আর বিয়ে কর নি?',
#   '',
#   "'না, বিয়ে করি নি।'",
#   '',
#   'আমি বললাম, যদি কখনো তুমি এই সাম্কেতিক লিপির অর্থ বের করতে পার তা',
#   'হলে কি আমাকে জানাবে? কী লেখা আছে আমি জানতে চাচ্ছি না আমি শুধু জানতে',
#   'চাই তোমার সাধনা সফল হয়েছে। তুমি সন্কেতের অর্থ ধরতে পেরেছ।',
#   '',
#   'এরিখ বলল, আমি তোমাকে কথা দিচ্ছি তুমি পৃথিবীর যে প্রান্তেই থাক আমি যদি',
#   'পাঠোষদ্ধার করতে পারি তুমি তা জানবে।',
#   '',
#   'পিএইচ. ডি. ডিগি নিয়ে আমি দেশে ফিরি ১৯৮৪ সনে। দশ বছর একনাগাড়ে',
#   'ঢাকা বিশ্ববিদ্যালয়ে মাস্টারি করি। লেখালেখির ব্যস্ততা খুব বেড়ে গেলে বিশ্ববিদ্যালয়',
#   'থেকে স্বেচ্ছায় অবসর গ্রহণ করি। ইউনিভার্সিটির সঙ্গে যোগাযোগ ছিন্ন হয়ে যায়।',
#   'ইউনিভার্সিটির ঠিকানায় চিঠিপত্র জমা হয়- আমি আনতে যাই না। গত ফেব্রুয়ারি',
#   'মাসে পেনশনস্ক্রান্ত জটিলতার জন্যে ইউনিভার্সিটিতে গিয়েছি। দেখি কয়েক বছরের',
#   'চার-পাচ শ চিঠি। বিদেশ থাকা আসা চিঠিগুলি আলাদা করে বাসায় নিয়ে এলাম।',
#   'একটি চিঠি এসেছে এরিখ স্যামসনের আইনজীবীর কাছ থেকে। আইনজীবী',
#   'জানাচ্ছেন- তার ক্লায়েন্ট এরিখ স্যামসন নিউমোনিয়ায় মারা গেছেন। ক্লায়েন্টের',
#   'নির্দেশমতো আমাকে জানাচ্ছেন যে এরিখ স্যামসন মৃত্যুশয্যায় লিপির পাঠোদ্ধার',
#   'করেছেন।',
#   '\x0c'],
#  ['__ প্রেসক্রিপশন _',
#   '',
#   'প্রচণ্ড মাথা ধরেছে।',
#   '',
#   'অনেকক্ষণ চেষ্টা করলাম মাথাধরাকে পান্তা না দিতে। অবহেলা কেট সইতে',
#   'পারে না। রোগও পারে না। রোগ যখন দেখে তাকে আমল দেয়া হচ্ছে না, অগ্রাহ্য করা',
#   'হচ্ছে তখন সে মনমেজাজ খারাপ করে চলে যায়। আমার ক্ষেত্রে তা হল না। পাস্তা না',
#   'পেয়ে মাথাধরা আরো বাড়ল। এক সময় লক্ষ্য করলাম মাথাধরাটা মেরুদণ্ড বেয়ে নিচে',
#   'নামার পরিকল্পনা করছে। ত্রিত ব্যবস্থা নেয়া প্রয়োজন-_আমি একটা ফামেসিতে ঢুকে',
#   'পড়লাম। চারটা প্যারাসিটামল কিনব। দুটা খেয়ে দুটা ভবিষ্যতের জন্যে পকেটে রেখে',
#   'দেব।',
#   '',
#   'আমার অনেকদিনের অভ্যাস যে কোনো দোকানে ঢোকার আগে দোকানের নাম',
#   'পড়ি। মাঝেমধ্যে সুন্দর সুন্দর নাম চোখে পড়ে। বেশ মজা লাগে। একটা স্টেশনারি',
#   "দোকানের নাম পেয়েছিলাম-_'নীলাচল' ৷ আরেকটা রেস্টুরেন্টের নাম 'ঝাল-বোল'।",
#   'সাধারণত দেখেছি সুন্দর নামের দোকানগুলি বেশিদিন চলে না। ঝাল-ঝোল এক',
#   'মাসের মধ্যে উঠে গেল। নতুন এক বেস্টুরেন্ট চালু হল। নাম-_দি নিউ মদিনা বিরিয়ানী',
#   'এন্ড কাবাব ঘর। সাইনবোর্ডে হাস্যমুখী দাড়িওয়ালা ছাগলের ছবি। এই বরেস্ট্রবেন্টটা',
#   'বেশ চলছে।',
#   '',
#   'যে কথা বলছিলাম- _ফার্মেসিতে ঢোকার আগে চট করে নাম পড়ে নিলাম। নতুন',
#   "কোনো নাম না হলেও আধুনিক নাম '্রসক্রিপশন'। আমার কাছে মনে হল নামটা শুধু",
#   'যে আধুনিক তা-ই নয়, বেশ জুতসই নাম। প্রসক্রিপশন মানেই তো ফার্মেসি',
#   '',
#   'চারটা প্যারাসিটামলের দাম চার টাকা। মাথাধরা নামক অতি যন্ত্রণাদায়ক ব্যাধির',
#   'জন্য বড়ই সপ্তা চিকিংসা। সেলসম্যানকে পানি দিতে বললাম। সে প্লাসে করে পানি',
#   'এনে দিল। দুটা ট্যাবলেট তখনই থেয়ে ফেললাম। ওষুধের দাম দিতে গিয়ে আমি',
#   'হততদ্ব। মনিব্যাগ সঙ্গে নেই। পকেটমার হয় নি এটা জানি। বাসা থেকে মনিব্যাগ',
#   '\x0c'],
#  ['ছাড়াই বের হয়েছি। দুটা ট্যাবলেট গিলে না ফেললে ফিরিয়ে দেয়া যেত। আমি খুবই',
#   'লজ্জার মধ্যে পড়লাম। কী বলব বুঝতে পারছি না। সেলসম্যানও যেন কেমন কেমন',
#   'করে তাকাচ্ছে',
#   '',
#   'দোকানের মালিক মনে হয় দূর থেকে ব্যাপারটা লক্ষ্য করছিলেন। তিনি এপিয়ে',
#   'এসে গম্ভীরমূুখে বললেন, আপনি একটু আমার ঘরে আসবেন? চারটা টাকার জনো',
#   'কঠিন কিছু কথা শুনতে হবে কি না বুঝতে পারছি না।',
#   '',
#   'আমি তার ঘরে ঢুকলাম এবং হড়বড় করে বললাম, ওষুধের দাম দিতে পারছি না।',
#   'কাল তোরে জমি এসে দিয়ে যাব।',
#   '',
#   'মালিক ভদ্রলোক বললেন, সামান্য লুটা ট্যাবলেটের দাম দিতে না পারায় আপনি',
#   'এরকম করছেন? ভাই এক কাজ করুন-__ দুই পাতা ট্যাবলেট নিয়ে যান। এর দাম',
#   'আপনাকে দিতে হবে না। আর শুনুন আপনি আমার সামনের চেয়ারে বসুন। চা দিতে',
#   'বলছি, গরম চা খান, মাথাধরাটা কমবে।',
#   '',
#   'আমি ভদ্ুলোকের ব্যবহারে মুগ্ধ হয়ে গেলাম। দিনকাল পাল্টে গেছে, প্রিয়জনদের',
#   'কাছ থেকেই ভালো ব্যবহার পাওয়া যায় না, আর এই ভদ্রলোক নিতান্তই অপরিচিত',
#   'একজন। আমি বললাম, আপনার নামটা জানতে পারি?',
#   '',
#   'ভদ্রলোক বললেন, অবশ্যই পারেন। আমার এমনই নাম যে একবার শুনলে',
#   'কখনো ভুলবেন না। আমার নাম কয়লা।',
#   '',
#   'আমি অবাক হয়ে বললাম, কয়লা?',
#   '',
#   'হ্যা কয়লা। রসিকতা করছি না। আসলেই আমার নাম কয়লা। জন্মের সময়',
#   'গায়ের রং ছিল খুবই ফরসা। আমার বাবা রহস্য করে বললেন, আমার ছেলে এমন',
#   'কয়লার মতো কালো হল ব্যাপারটা কী? সেই থেকে কয়লা নাম। ঠাট্টা করে কয়লা',
#   "ডাকতে ডাকতে-_কয়লা। ভালো নাম মোহম্মদ সানোয়ার হোসেন।'",
#   '',
#   'সানোয়ার সাহেবের দিকে ভালো করে তাকালাম। ভদ্রলোকের গায়ের রঙই যে',
#   'শুধু সুন্দর তাই না, দেখতেও সুন্দর। বয়স চষ্ট্রেশের মতো হবে। চুলে পাক ধরেছে।',
#   'তার জন্যে মনে হয় ভদ্রলোককে আরো সুন্দর লাগছে। কিছু মানুষ আছে যাদের পাকা',
#   'চুলে মানায়।',
#   '',
#   '"আপনার মাথাধরার অবস্থা কী?\'',
#   '',
#   "“কমে জাসছে।'",
#   '',
#   'সানোয়ার সাহেব রহস্যময় গলায় বললেন, এক মিনিটের জন্যে চোখটা বন্ধ',
#   'করবেনা',
#   '',
#   "'কেনঃ'",
#   '',
#   '"আপনার কপালে এবং চোখে একটা মলম লাগিয়ে দেব? বার্মিজ মলম। নাম',
#   "টাইগার বাম। লাগাবার তিন মিনিটের যথ্যে মাথাধরা চলে যাবে।'",
#   '\x0c'],
#  ['আমি চোখ বন্ধ করলাম। ভদ্রলোক চোখের পাতায় এবং কপালে বাম ঘষে',
#   'দিলেন। খুবই আরামদায়ক ম্যাসাজ। ম্যাসাজের কারণেই মনে হয় বাথা অর্ধেক কমে',
#   'গেল।',
#   '',
#   '"তিন মিনিট চোখ বন্ধ করে রাখবেন। খুলবেন না।\'',
#   '',
#   'আমি চোখ বন্ধ করেই বললাম. আপনার দোকানে মাথাধরা নিয়ে যারা আসে',
#   'তাদের সবার চোখেই কি আপনি টাইগার বাম ঘষে দেনা',
#   '',
#   "'না, দেই না। আপনি লেখক মানুষ আপনার জন্যে অন্য ব্যবস্থা।'",
#   '',
#   "*ও আচ্ছা।'",
#   '',
#   'চা চলে এল চায়ের সঙ্গে গরম শিক্গাড়া। আগুনগরম শিক্ষাড়া সব সময় ভালো',
#   'হয়__এটা মনে হল আরো ভালো। চা-টা শিক্ষাড়ার মতো ভালো না হলেও খারাপ না।',
#   'লেখক হিসেবে মাঝেমধ্যে অপ্রত্যাশিত কিছু খাতির-যত্ন পাই। বড় মাপের লেখকরা এ',
#   'ধরনের খাতির-যত্ধে বিত্তুত এবং বিরক্ত হন। যেহেতু আমি খুবই ছোট মাপের',
#   'একজন. আমি খুশি হই। অবিশ্যি চেষ্টা থাকে খুশি চেপে রাখার।',
#   '',
#   'চা খেতে খেতে আমি ভদ্রলোকের বসার ঘর দেখলাম। তার ফার্মেসির নামে',
#   'যেমন রুচির পরিচয় পাওয়া যায় ঘর থেকেও পাওয়া যায়। সুন্দর করে সাজানো ঘর।',
#   'মেঝেতে কার্পেট। চারদিকে নানান ধরনের ইনভোর প্ল্যান্ট রাখা। একটা প্ল্যান্টে আবার',
#   'বোতামের মতো নীল ফুল ফুটেছে। অপূর্ব দেখাচ্ছে। ব্যবসায়ী মানুষের বসার ঘরে',
#   'সাধারণত প্ল্যান্ট দেখা যায় না। ভদ্রলোকের টেবিলে দুটা বই, একটার নাম',
#   '',
#   '[11548',
#   '৯1৫',
#   '1416 8001 ৫৫৩81),',
#   'অন্যটার নাম পড়া যাচ্ছে না। সেটিও নিশ্চয় গজ-উপন্যাসের বই না, সিরিয়াস কোনো',
#   'ভে ঠোটে',
#   '1',
#   '',
#   'সানোয়ার সাহেব বললেন, আমার বাবার ছবি।',
#   '',
#   '"আমি ভেবেছিলাম আপনার যুবক বয়সের ছবি।\'',
#   '',
#   '"অনেকেই তাই ভাবেন। অফিসঘরে নিজের ছবি টাঙিয়ে রাখব এত অহংকার',
#   'এখনো আমার হয় নি।”',
#   '',
#   'আমি বললাম, আপনার বাবা অত্যন্ত সুপুরুষ ছিলেন। সিনেমার নায়কের মতো',
#   'চেহারা।',
#   '',
#   'সানোয়ার সাহেব হাসতে হাসতে বললেন, আমার বাবা ছীবনের বেশিরভাগ সময়',
#   'ব্যয় করেছেন ছবিতে ঢোকার কৌশল বের করতে গিয়ে। তিনি সকালবেলা',
#   'এফডিসিতে চুকতেন, রাত এগারটা-বারটার সময় ফিরতেন। যেতেন খুব সেজেগুজে ৷',
#   '\x0c']]

# %% [markdown]
# Clean text
#
# Search for patterns in the text. When found, just remove.

# %%
for i, _data in enumerate(data):
    temp = [] # temp store
    for line in _data:
        temp.extend(line.split("|")) # where string will be split
    data[i] = temp

for i, _data in enumerate(data):
    temp = []
    for line in _data:
        temp.extend(line.split(" ")) # where string will be split
    data[i] = temp
    
for i, _data in enumerate(data):
    temp = []
    for line in _data:
        temp.extend(line.split("-")) # where string will be split
    data[i] = temp

for i, _data in enumerate(data):
    temp = []
    for line in _data:
        temp.extend(line.split(",")) # where string will be split
    data[i] = temp
    
for i, _data in enumerate(data):
    temp = []
    for line in _data:
        temp.extend(line.split("?")) # where string will be split
    data[i] = temp
    
for i, _data in enumerate(data):
    temp = []
    for line in _data:
        temp.extend(line.split("!")) # where string will be split
    data[i] = temp

# %% [markdown]
# Further clean text
#
# Remove special characters

# %%
# remove or ignore all chars present in the 'ignore_list'
ignore_list = "!#$%&'()\n”*+”“,-.৷'/:;<=>?[]@\^_|`{|}~।ঃ"+'"' 

for i, _data in enumerate(data):
    temp = []
    
    for word in _data:
#         print(word)

        for char in word:
            if char in ignore_list:
                word = word.replace(char, '')
            if char.isdigit():
                word = word.replace(char, '') 
        if len(word) != 0: 
            temp.append(word)    
    data[i] = temp

# %% [markdown]
# Create a dictionary : each page numbger is the key, the list of words in each page is the value

# %%
dictionary = {}

for i ,_data in enumerate(data):
    dictionary[i] = _data

# %% [markdown]
# #### Print the dictionary. How many mis-spelled words can you recognize?
#
# What are the reasons can you think behind these bad recognition?
# Hint: Look at the pdf file.

# %%
 print(dictionary)
# Out:
# {0: ['অন্তরার', 'বাবা', 'মফিজাউদ্দিন', 'সাহেব', 'নির্বিরোধী', 'মানুষ', 'প্রাইভেট', 'ব্যাংকে', 'ফরেন', 'এক্সচেঞ্জ', 'বিভাগে', 'কাজ', 'করেন', 'ঢাকার', 'মালিবাগে', 'ফ্ল্যাট', 'ভাড়া', 'করে', 'থাকেন', 'চিপা', 'গলির', 'ভেতর', 'ফ্ল্যাট', 'গাড়ি', 'ঢোকে', 'না', 'বলে', 'বেশ', 'সম্তা', 'চার', 'রুমের', 'বাইশ', 'শ', 'স্কয়ার', 'ফিটের', 'ফ্ল্যাট', 'তাড়া', 'তিন', 'হাজার', 'টাকা', 'মফিজউদ্দিন', 'সাহেবের', 'সংসার', 'ছোট', 'স্ত্রী', 'দুই', 'মেয়ে', 'এক', 'ছেলে', 'বড়', 'মেয়েটির', 'বিয়ে', 'হয়ে', 'গেছে', 'কানাডায়', 'স্বামীর', 'সঙ্গে', 'থাকে', 'ছোট', 'মেয়েটিরও', 'বিয়ের', 'কথা', 'হচ্ছে', 'পাত্র', 'পক্ষ', 'মেয়ে', 'দেখে', 'গেছে', 'ফাইন্যাল', 'কিছু', 'না', 'বললেও', 'মেয়ে', 'যে', 'তাদের', 'খুব', 'পছন্দ', 'এটা', 'বোঝা', 'যাচ্ছে', 'ছেলেটাও', 'পড়াশোনায়', 'তভালো', 'জ্বলাই', 'মাসে', 'অনার্স', 'পরীক্ষা', 'দেবে', 'পাস', 'করে', 'বের', 'হয়ে', 'কোথাও', 'চাকরি', 'না', 'পেলে', 'ব্যাহকে', 'চাকরি', 'হবেই', 'মফিজউদ্দিন', 'সাহেব', 'তার', 'ব্যাংকের', 'এমডি', 'সাহেবকে', 'বলে', 'রেখেছেন', 'কাজেই', 'মফিজউদ্দিন', 'সাহেবকে', 'মোটামুটি', 'সফল', 'এবং', 'সুখী', 'মানুষ', 'বলা', 'যেতে', 'পারে', 'তার', 'স্ত্রী', 'ভাগ্যও', 'ভালো', 'রেহানা', 'অতি', 'শান্ত', 'স্বতাবের', 'মেয়ে', 'স্বামীর', 'সঙ্গে', 'তার', 'যে', 'ঝগড়াটগড়া', 'হয়', 'না', 'তা', 'না', 'মাঝেমধ্যে', 'হয়', 'তবে', 'তখনো', 'যফিজ', 'সাহেবের', 'কী', 'দরকার', 'কী', 'দরকার', 'না', 'তার', 'দিকে', 'কঠিন', 'নজর', 'থাকে', 'ব্যাংক', 'থেকে', 'ফিরতে', 'মফিজ', 'সাহেবের', 'রোজই', 'সন্ধ্যা', 'সাতটা', 'আটটা', 'বেজে', 'যায়', 'তিনি', 'ফিরেই', 'গরম', 'পানি', 'দিয়ে', 'গোসল', 'কবেন', 'গোসল', 'সেরেই', 'খেতে', 'বসেন', 'খাওয়া', 'শেষ', 'করে', 'মিনিট', 'দশেক', 'চোখ', 'বন্ধ', 'করে', 'শুয়ে', 'থাকেন', 'তারপর', 'এসে', 'টিভির', 'সামনে', 'বসেন', 'নাটক', 'থাকলে', 'নাটক', 'দেখেন', 'নাটক', 'না', 'থাকলে', 'ভিসিপিতে', 'হিন্দি', 'ছবি', 'দেখেন', 'পুরোনো', 'ছবি', 'দুবার', 'তিনবার', 'করে', 'দেখতেও', 'তাঁর', 'কোনো', 'আপত্তি', 'নেই', 'তবে', 'পুরোনো', 'ছবি', 'যেন', 'তাকে', 'দেখতে', 'না', 'হয়', 'রেহানার', 'সেদিকেও', 'নজর', 'আছে', 'বাসায়', 'কেউ', 'না', 'থাকলে', 'তিনি', 'নিজেই', 'ভিডিও', 'রব', 'থেকে', 'ছবি', 'নিয়ে', 'আসেন', 'হিন্দি', 'ছবি', 'দেখার', 'ব্যাপারে', 'তার', 'কোনো', 'আগ্রহ', 'নেই', 'তবু', 'স্বামীকে', 'খুশি', 'করার', 'জন্যে', '\x0c'], 1: ['তিনি', 'বলেন', 'নাচ', 'গান', 'আসলে', 'আমাকে', 'ডাক', 'দিও', 'তো', 'তোমার', 'সঙ্গে', 'বসে', 'দেখব', 'মফিজ', 'সাহেব', 'সুবোধ', 'স্বামীর', 'মতো', 'নাচ', 'গানের', 'জায়গা', 'এলে', 'স্ত্রীকে', 'ছাকেন', 'স্বামী', 'স্ত্রীর', 'সাংসারিক', 'কথাবার্তা', 'ছবি', 'দেখার', 'সময়ই', 'হয়', 'কারণ', 'মফিজ', 'সাহেব', 'ছবি', 'শেষ', 'করেই', 'ঘুমাতে', 'যান', 'তাকে', 'খুব', 'ভোরে', 'উঠতে', 'হয়', 'প্রাইভেট', 'ব্যাংক', 'নটা', 'থেকে', 'ব্যাংকিং', 'আওয়ার', 'মফিজ', 'সাহেবের', 'জীবনযাত্রা', 'এভাবেই', 'চলছিল', 'এক', 'বুধবারে', 'সামান্য', 'ব্যতিক্রম', 'হল', 'তিনি', 'পলিথিনের', 'এক', 'পোটলা', 'নিয়ে', 'অফিস', 'থেকে', 'ফিরে', 'যথারীতি', 'গোসল', 'করতে', 'গেলেন', 'গোসলের', 'মাঝখানে', 'রেহানা', 'বাথরুমের', 'দরজায়', 'ধাক্কা', 'দিয়ে', 'বললেন', 'পোলার', 'ভেতর', 'কাপড়', 'কিসের', 'মফিজ', 'সাহেব', 'বললেন', 'আমার', 'কাপড়', 'তোমার', 'কী', 'কাপড়', 'কিনলাম', 'আর', 'কি', 'কিনবে', 'তো', 'বটেই', 'বিনা', 'টাকায়', 'তোমাকে', 'কে', 'কাপড়', 'দিবে', 'কিসের', 'কাপড়', 'কাফনের', 'কাপড়', 'কাফনের', 'কাপড়', 'মানে', 'কী', 'মফিজ', 'সাহেব', 'জবাব', 'দিলেন', 'না', 'মাথায়', 'পানি', 'ঢালতে', 'লাগলেন', 'রেহানা', 'বললেন', 'জবাব', 'দিচ্ছ', 'না', 'কেন', 'কাফনের', 'কাপড়', 'মানে', 'কী', 'কার', 'কাফনের', 'কাপড়', 'তোমার', 'কথা', 'তো', 'কিছুই', 'বুঝতে', 'পারছি', 'না', 'তৃমি', 'কি', 'মারা', 'গেছ', 'নাকি', 'যে', 'তোমার', 'কাফনের', 'কাপড়', 'গোসলটা', 'একটু', 'বন্ধ', 'রেখে', 'কথার', 'জবাব', 'দাও', 'তো', 'আমার', 'এক', 'কলিগ', 'হজ', 'করতে', 'গিয়েছিলেন', 'তাকে', 'আনতে', 'বলেছিলাম', 'মক্কা', 'থেকে', 'তোমার', 'জন্যে', 'কাফনের', 'কাপড়', 'আনতে', 'বলেছ', 'কেন', 'দেশে', 'সাদা', 'কাপড়', 'পাওয়া', 'যায়', 'না', 'কাবা', 'শরিফ', 'ছুয়ায়ে', 'এনেছে', 'কাবা', 'শরিফ', 'ছুঁয়ায়ে', 'তোমার', 'জন্যে', 'কাফনের', 'কাপড়', 'আনতে', 'হবে', 'কেন', 'মফিজ', 'সাহেব', 'গোসল', 'শেষ', 'করে', 'বের', 'হলেন', 'শাস্ত', 'গলায়', 'রললেন', 'ভাত', 'দাও', 'ভাত', 'দাও', 'মানে', 'তুমি', 'আগে', 'বল', 'কাফ ...

# %% [markdown]
# #### Save cleaned data to a json file.
#
# You need add a few keywords to the following lines of codes so that you can open Bangla text in the out file.

# %%
with open("out_testscript_02.json", "w",encoding='utf-8') as outfile:
  json.dump(dictionary, outfile,ensure_ascii=False)

# %% [markdown]
# #### Collect the words from all pages in a single list
#
# Hint: you will need a do loop and a new list

# %%
all_words=[]
for i in dictionary.keys():
  for w in dictionary[i]:
    all_words.append(w)

# %%
len(all_words)
# Out:
# 6747

# %%
all_words = pd.DataFrame(all_words, columns=["words"])
all_words.head()
# Out:
#          words
# 0      অন্তরার
# 1         বাবা
# 2  মফিজাউদ্দিন
# 3        সাহেব
# 4   নির্বিরোধী

# %% [markdown]
# #### Count the number of each word
# Hint : you can do this in 2 ways: 1) use `numpy unique method` applied on the created list above or 2) create a dataframe with one column which will have each word as a row. Then you can use pandas `value_count` method.

# %%
unique_value = all_words.value_counts().rename_axis("Unique_value").reset_index(name="Counts")

# %%
unique_value.head(50)
# Out:
#    Unique_value  Counts
# 0            না     188
# 1           আমি     121
# 2          আমার      84
# 3           করে      82
# 4           তার      70
# 5          তুমি      55
# 6            কী      54
# 7            এই      52
# 8         তোমার      45
# 9            সে      43
# 10          হয়      43
# 11        নিয়ে      38
# 12          কথা      37
# 13           এক      34
# 14        কাপড়      34
# 15         থেকে      33
# 16           তো      32
# 17         কোনো      32
# 18         একটা      31
# 19          কেন      30
# 20        সঙ্গে      30
# 21        বললাম      29
# 22          নাম      28
# 23           তা      28
# 24      কেরোলিন      27
# 25         হয়ে      26
# 26         কিছু      26
# 27        বললেন      25
# 28
#       25
# 29         করতে      25
# 30        জন্যে      25
# 31          মতো      25
# 32          আছে      24
# 33           হল      24
# 34          হবে      24
# 35        দিয়ে      24
# 36           যে      23
# 37         গল্প      23
# 38           আর      23
# 39       কাফনের      23
# 40          মনে      23
# 41          ছবি      22
# 42        হচ্ছে      22
# 43          এবং      22
# 44      টেলিফোন      22
# 45           নি      22
# 46       হয়েছে      21
# 47        আমাকে      21
# 48          খুব      20
# 49         ভালো      20

# %% [markdown]
# #### Do you see the potential challenges in extarcting Bangla text using pytesseract?
#
# How else would you proceed? in terms of data, in terms of algorithm.

# %% [markdown]
# Potential challenges are quality Images, the training dataset of the Bangla language, Stemmer,  etc.
# I would proceed by details learning Optical character recognition (OCR) algorithm
